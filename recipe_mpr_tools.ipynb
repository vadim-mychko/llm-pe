# %%
import pandas
import json
import numpy as np

# %%
base_data_path = "/Users/david/Documents/Research2324/Sanner/data/500QA.json"

# %%
# Load in recipe-mpr 500QA
with open(base_data_path) as base_data_file:
    base_data = json.load(base_data_file)

# %% [markdown]
# ## 1000 items - get all unique recipes first

# %%
# FS examples
fs_exs = ['Salsa made with pineapple, mangoes, onions, black beans, corn, strawberries, jalapeno, and tomatoes',
          'Sweet chinese red bean bun',
          'Chocolate cupcakes with blue vanilla custard filling hidden inside the cupcake',
          'Thai curry with shrimp and coconut milk that can be dipped with bread',
          'Breakfast quiche with onions, swiss cheese, and bacon'
]

# %%
all_items = []
for query_set in base_data:
    for key, option in query_set['options'].items():
        if not (option in all_items or option in fs_exs):
            all_items.append(option)

# %%
len(all_items)
# Out:
# 1827

# %%
# Randomly select 1000 items
np.random.seed(42)
keep_indices = list(np.random.choice(range(len(all_items)), size=(1000,), replace=False))
items_1000_dict = {}
for i in range(1000):
    items_1000_dict[i] = {'description': all_items[keep_indices[i]]}
items_1000_dict
# Out:
# {0: {'description': 'Zucchini stir-fried with salad oil, water, salt, and sugar'},
#  1: {'description': 'Chinese style ribs made from sparerib racks, fresh ginger, and honey'},
#  2: {'description': 'Regular dinner rolls with honey'},
#  3: {'description': 'Roasted almonds'},
#  4: {'description': 'A Mexican take of traditional Filipino Adobo chicken with noodles'},
#  5: {'description': 'Caramel apple jam made with granny smith and braeburn apples'},
#  6: {'description': 'Swedish meatballs - beef and pork meatballs with savoury mushroom gravy'},
#  7: {'description': 'Indian vegan tikka masala curry that tastes like chicken'},
#  8: {'description': 'Iced strawberry smoothie with ginger, lime, and honey added'},
#  9: {'description': 'Sauteed kale with onion, olive oil, and sea salt'},
#  10: {'description': 'Dinner waffles with deli turkey'},
#  11: {'description': 'Not Difficult At All: Oi-sobagi (Stuffed Cucumber Kimchi) recipe'},
#  12: {'description': 'Quinoa cake with fruits and nuts that is diary-free'},
#  13: {'description': 'Breakfast pizza with sausage, cheddar, sour cream and jalapenos'},
#  14: {'description': 'Sugar cookies with icing containing butter and milk'},
#  15: {'description': 'Stir fry made of pork belly and flavoured with ginger and soy sauce'},
#  16: {'description': 'McDonalds-style fries made from russet potatoes'},
#  17: {'description': 'Mini corndogs'},
#  18: {'description': 'High protein, low fat eggs, spinach, and vegetables mixed together in a pan and cooked to make an omelette'},
#  19: {'description': 'Smoothie containing strawberries, bananas, yogurt, and nonfat milk'},
#  20: {'description': 'Spicy snack with puffed rice cereal, wasabi peas, pumpkin seeds, and roasted soybeans'},
#  21: {'description': 'Mozzarella cheese recipe'},
#  22: {'description': 'Tropical fruit salad containing mangoes, papayas, pineapple, kiwi fruits, and banana'},
#  23: {'description': 'West African soup made of squash, flavoured with chili powder, and smoothed out with coconut milk'},
#  24: {'description': 'Spicy chocolate milkshakes'},
#  25: {'description': 'Stir-fried cauliflower, beans, and carrots'},
#  26: {'description': 'Grilled cabbage'},
#  27: {'description': 'Quick to make, cereal made with blueberries'},
#  28: {'description': 'Capellini pasta with breadcrumbs, walnuts, raisins, and other seasoning'},
#  29: {'description': 'Gingerbread flavoured waffles'},
#  30: {'description': 'A high-protein dessert that uses Tofu with crushed almond'},
#  31: {'description': 'Spicy seasoning made from black pepper, onion, and garlic'},
#  32: {'description': 'Crepes with blueberries, strawberry jam, cherry brandy, and lemon juice'},
#  33: {'description': 'Protein box made from eggs, fruit, and yogurt'},
#  34: {'description': 'Cajun seafood gumbo made with rice and shrimp'},
#  35: {'description': 'Vitamin-rich soup made with vegetables'},
#  36: {'description': 'Assortment of shredded vegetables with pineapples and seasoning'},
#  37: {'description': 'A drink made with Vodka and orange'},
#  38: {'description': 'Quick guacamole made with avocados, salsa, and lime juice'},
#  39: {'description': 'Three bean salad with spicy peppers and Italian dressing'},
#  40: {'description': 'Detox green juice made from cilantro, ginger, lemon, lime, cucumbers'},
#  41: {'description': 'Stir fried Japanese Shirataki noodles (low calorie noodles)'},
#  42: {'description': 'Steak and kidney pie'},
#  43: {'description': 'German chicken soup with shell noodles'},
#  44: {'description': 'Pasta made with grains, broccoli, cherries, olives, and parmesan requiring only light preparation and no cooking'},
#  45: {'description': 'Salmon cooked in the oven, seasoned with garlic, onion, cumin, dill, and lime'},
#  46: {'description': 'Shanghainese dumpling with prawn, chicken, and chinese cabbage as filling'},
#  47: {'description': 'Italian coffee with Amaretto and brandy added'},
#  48: {'description': 'Garlic butter strip steaks cooked with onions'},
#  49: {'description': 'Angelhair pasta with pomodoro sauce'},
#  50: {'description': 'Lemonade flavoured fluffy scones'},
#  51: {'description': 'Pesto tuna sandwich - sandwich filled with canned tuna mixed with pesto and mayonnaise'},
#  52: {'description': 'Mexican salad made from beans and corn'},
#  53: {'description': 'Soup made with carrots, pepper, celery, and egg noodles to use up the fridge leftovers'},
#  54: {'description': 'High fiber salad with peas and quinoa'},
#  55: {'description': 'Healthy vegetable chips made from sweet potatoes'},
#  56: {'description': 'Low calorie low fat tuna salad'},
#  57: {'description': 'Smoothie with yogurt, chocolate, and raspberries'},
#  58: {'description': 'Chicken cooked and flavored with lemon sauce'},
#  59: {'description': 'Round steak with cream of mushroom soup'},
#  60: {'description': 'Beef roasted in salt crust'},
#  61: {'description': 'Baguette stuffed with italian sausage and spinach'},
#  62: {'description': 'Tortellini pasta with bacon, heavy cream, and peas'},
#  63: {'description': 'Peaches and cream ice cream'},
#  64: {'description': 'Blueberry iced tea (non-alcoholic)'},
#  65: {'description': 'Cream puffs made with low-fat margarine'},
#  66: {'description': 'Caked with baked with nuts, bananas, and no animal byproducts'},
#  67: {'description': 'Ice cream made from vanilla and sweetened cream churned at home'},
#  68: {'description': 'Cake baked with apples and walnuts'},
#  69: {'description': 'Dessert treat made with butter, mini marshmallows, and Rice Krispie cereal'},
#  70: {'description': 'Orange-flavoured cake baked with walnuts'},
#  71: {'description': 'Beef and carrot stew with dark beer'},
#  72: {'description': 'Mushrooms cooked in a fried with breading'},
#  73: {'description': 'Keto chocolate peanut butter fudge'},
#  74: {'description': 'Vegetable salad containing onions, tomatoes, capsicum, and cabbage'},
#  75: {'description': 'German style pan fried flat cut of beef'},
#  76: {'description': 'Beef skewers made with pineapple juice and brown sugar'},
#  77: {'description': 'Whole wheat banana muffins without the use of oil'},
#  78: {'description': 'Assorted vegetables with cayenne pepper'},
#  79: {'description': 'Corn dogs - deep fried sausages coated in thick batter'},
#  80: {'description': 'German iced coffee made from whipped cream, sweet chocolate, wafer cookies, vanilla ice cream, coffee'},
#  81: {'description': 'Low fat brownie made with fudge'},
#  82: {'description': 'Rice ball with corned beef and egg'},
#  83: {'description': 'Ice cream made with whole milk and Oreo cookies'},
#  84: {'description': 'Vegan pumpkin pancakes'},
#  85: {'description': 'Cat food with tuna and chicken livers'},
#  86: {'description': 'Popeyes wrap from chicken breasts, spinach, and cheese; seasoned with mayonnaise and pepper'},
#  87: {'description': 'Hawaiian sushi made with SPAM'},
#  88: {'description': 'Italian chicken made from skinless chicken, cheese blend, and breadcrumbs'},
#  89: {'description': 'No salt added snack bars made with pecans'},
#  90: {'description': 'Caesar salad dressing recipe made from scratch using raw cashews'},
#  91: {'description': 'Soup made with cabbage, carrots, potatoes, and onions'},
#  92: {'description': 'Soft and juicy russian meatball with creamy tomato sauce'},
#  93: {'description': 'Mushroom and lettuce salad with green onions'},
#  94: {'description': 'Easter chocolate bunnies made from milk chocolate'},
#  95: {'description': 'Chicken breasts made using the oven, with garlic'},
#  96: {'description': 'Paleo taco salad made with ground beef'},
#  97: {'description': 'Bacon, lettuce and tomato waffle sandwich'},
#  98: {'description': 'Boston cinnamon cookies with walnut and raisins'},
#  99: {'description': 'Fried chicken wings made with buttermilk and vegetable shortening'},
#  100: {'description': 'Chicken made using a pan'},
#  101: {'description': 'Beef chili containing jalapeno pepper, chili powder, cayenne pepper, and ground chipotle chile pepper'},
#  102: {'description': 'Pancakes with berries'},
#  103: {'description': 'Chirashi sushi made with salmon roe'},
#  104: {'description': 'Chocolate brownie recipe with milk and maple syrup'},
#  105: {'description': 'Fruit kebabs made of strawberry, kiwi, bananas, and more fruits'},
#  106: {'description': 'Kale sauteed with chicken stock and sherry wine vinegar'},
#  107: {'description': 'Low fat cookies containing apple sauce and whole wheat flour'},
#  108: {'description': 'Cheddar cheese and elbow macaroni with onions'},
#  109: {'description': 'Bananas and strawberries blended in milk'},
#  110: {'description': 'Pasta salad made with vegetables'},
#  111: {'description': 'Gluten-free, dairy-free, egg-free pancakes'},
#  112: {'description': 'Confetti cupcakes with buttercream icing'},
#  113: {'description': 'Low fat smoothie with yogurt, chocolate, and berries'},
#  114: {'description': '2-ingredient yogurt from scratch'},
#  115: {'description': 'Macaroni made with ricotta, parmesan, cheddar, mozzarella, and cream cheese'},
#  116: {'description': 'Poke patties made from mixture of tuna, egg, and breadcrumbs'},
#  117: {'description': 'Berry flavored alcoholic beverage'},
#  118: {'description': 'Creamy rotini pasta containing spinach and parmesan cheese'},
#  119: {'description': 'Japanese rice ball wrapped with nori (seaweed)'},
#  120: {'description': 'Strawberry and spinach salad with a strawberry yogurt dressing'},
#  121: {'description': 'Salmon fish cooked in the oven with parmesan cheese and seasoned pepper, cayenne pepper, and lemon juice'},
#  122: {'description': 'Ribeye steak marinade'},
#  123: {'description': 'Real passion fruit juice'},
#  124: {'description': 'Breakfast tea for keto diet'},
#  125: {'description': 'Classic rice krispie treats - marshmallow and rice krispies cereal bar'},
#  126: {'description': 'Street-cart-style chicken salad'},
#  127: {'description': 'Sweet potato soft tacos'},
#  128: {'description': 'Baked peach dessert with vanilla ice cream'},
#  129: {'description': 'Astragalus vegetable soup (detox soup)'},
#  130: {'description': 'Breaded cauliflower bites with buffalo flavouring'},
#  131: {'description': 'Pancakes made from organic whole wheat flour'},
#  132: {'description': 'Candy that is chewy and hard with a butterscotch flavour'},
#  133: {'description': 'Chicken and vegetable fettuccine made using milk, cream cheese, and parmesan cheese'},
#  134: {'description': 'Soup with beef, vegetables, and seasoning'},
#  135: {'description': 'Tukey kebab flavoured with salt and pepper'},
#  136: {'description': 'Hard candy'},
#  137: {'description': 'A small potato dough dumpling that is Italian in origin'},
#  138: {'description': 'Sweet Quebec beans made with maple syrup and molasses'},
#  139: {'description': 'Salad with mayonnaise sauce mixed with shredded imitation crab meat'},
#  140: {'description': 'Cookies made from brown sugar and splenda sugar substitute'},
#  141: {'description': 'Soft and chewy M&M cookies'},
#  142: {'description': 'Stuffing balls made of leftover meat stuffing, egg, and cheese'},
#  143: {'description': 'Egg noodle dish with bacon, green peppers, tomatoes, and cheese'},
#  144: {'description': 'Low fat tiramisu made with ladyfingers, nonfat milk, and brandy'},
#  145: {'description': 'Cookies with fried fruit'},
#  146: {'description': 'Halal Iraqi stuffed zucchini with rice'},
#  147: {'description': 'Pizza made with three types of cheese, 2 types of sausage, and pepperoni'},
#  148: {'description': 'Seasoning for beef stew'},
#  149: {'description': 'Real pomegranate juice'},
#  150: {'description': 'West African meat kebabs'},
#  151: {'description': 'Bacon, lettuce, and tomato pizza with monterey jack cheese and cream cheese'},
#  152: {'description': 'Glaze made from semisweet chocolate and water'},
#  153: {'description': 'Iced coffee with cinnamon and anise'},
#  154: {'description': 'Chicken and brocoli stir fry with soy sauce'},
#  155: {'description': 'Spicy chicken with chili oil'},
#  156: {'description': 'Spicy Chicken Fajitas'},
#  157: {'description': 'Creamy cheese cake recipe'},
#  158: {'description': 'Salad made with tuna that is low fat and protein-packed'},
#  159: {'description': 'Pan-fried noodles with hoisin beef'},
#  160: {'description': 'Soup made from mango puree, sweetened condensed milk, orange juice, and papayas'},
#  161: {'description': 'Classic chicken tenders - deep fried boneless chicken strips'},
#  162: {'description': 'Wide egg noodles, chicken legs, onions, carrots, and celery in chicken broth'},
#  163: {'description': 'French fruit tart with grapes, kiwi, and strawberries'},
#  164: {'description': 'Salad made from lettuce and sugar'},
#  165: {'description': 'Recipe for bacon wrapped duck breasts with Italian salad dressing'},
#  166: {'description': 'Egg imitation made with seeds'},
#  167: {'description': 'Pumpkin seed soup containing tomatoes, onion, habanero peppers, shrimp, and spinach'},
#  168: {'description': 'Peanut butter cookies that are gluten-free and sugar-free'},
#  169: {'description': 'Creamy asparagus bake with cheddar cheese'},
#  170: {'description': 'Iced coffee made with cold coffee and ice cream'},
#  171: {'description': 'Salmon fish cooked in the oven with garlic, soy sauce, and lemon juice'},
#  172: {'description': 'Alcoholic tea with shots of whiskey'},
#  173: {'description': 'Vanilla pudding salad containing cantaloupe, watermelon, nectarines, strawberries, blueberries, and grapes'},
#  174: {'description': 'Guacamole made from avocado and onions'},
#  175: {'description': 'Peach drink made with peach nectar and orange juice'},
#  176: {'description': 'Italian meatballs and pasta sprinkled with parmesan'},
#  177: {'description': "Fried rice paired with seasoned shrimp and vegetables that doesn't take many steps"},
#  178: {'description': 'An alcoholic cocktail made of banana liqueur'},
#  179: {'description': 'Carrots, shiitake mushrooms, and leeks with miso seasoning'},
#  180: {'description': 'Chicken, mushroom, and tomato baked in a sauce mixture'},
#  181: {'description': 'Savory and not very spicy japanese beef curry'},
#  182: {'description': 'Punch made from rose syrup and vodka'},
#  183: {'description': 'Spicy Chinese-style chicken wings with szechuan peppercorns'},
#  184: {'description': 'Recipe for low calorie dairy vanilla ice cream'},
#  185: {'description': 'Meat sauce containing tomato sauce, ground turkey, onion, dried basil, and red wine'},
#  186: {'description': 'Pastry cream made with egg yolks, milk, and sugar'},
#  187: {'description': 'Caviar served directly on ice'},
#  188: {'description': 'Snack assortment of blueberries, almonds, and yogurt'},
#  189: {'description': 'Brussel sprouts made with a vinaigrette'},
#  190: {'description': 'Rye bread snack made from sausage and cheese'},
#  191: {'description': 'Crunchy greasy beefy potato tacos'},
#  192: {'description': 'Baked apple crumble pastry'},
#  193: {'description': 'Barbecue pork ribs with a tangy sauce'},
#  194: {'description': 'Easy broccoli recipe made with olive oil, salt and pepper'},
#  195: {'description': 'Ribs made with south african spices'},
#  196: {'description': 'Rice flour sponge cake for beginners to make'},
#  197: {'description': 'Grilled tuna with grilled bread and Aioli'},
#  198: {'description': 'Low-fat coconut alcohol-free cocktail'},
#  199: {'description': 'Seasoning salt for fries, made from cumin, chili etc.'},
#  200: {'description': 'Salmon cooked with edamame and carrots'},
#  201: {'description': 'Wraps that are low in carb'},
#  202: {'description': 'Beer-battered fried avocado Wedges'},
#  203: {'description': 'Potatoes cooked with onions over a campfire'},
#  204: {'description': 'Fried fish made with fried potato chips'},
#  205: {'description': 'Low-fat pastry cream'},
#  206: {'description': "Pineapple coconut smoothie that's made with almond milk"},
#  207: {'description': 'Sushi filled with avocado, carrot, and cucumber'},
#  208: {'description': 'Low calories dandan noodles made with doubanjiang (spicy bean) sauce'},
#  209: {'description': 'Eggs benedict - poached eggs, prosciutto on top of English muffins topped with a creamy Hollandaise sauce'},
#  210: {'description': 'Pot roast meat loaf'},
#  211: {'description': 'Stir-fried egg and tomato garnished with green onion'},
#  212: {'description': 'Pumpkin thai stir fry with peanuts, basil and fish sauce'},
#  213: {'description': 'Lobster boiled with butter'},
#  214: {'description': 'Grilled ribs with ground black pepper'},
#  215: {'description': 'Low sodium soft tacos'},
#  216: {'description': 'Chili sauce made from tomato, vinegar, and onions. Seasoned with salt, lemon juice, and garlic powder'},
#  217: {'description': 'Homemade pastry dough'},
#  218: {'description': 'Smoothie with tomato juice and cucumbers'},
#  219: {'description': "Classic shephard's pie - casserole made from mashed potatoes and chicken stew"},
#  220: {'description': 'Onion dip potato salad'},
#  221: {'description': 'Very low-fat assortment of shredded vegetables with seasoning'},
#  222: {'description': 'Beef meatballs cooked in canned soup, ready in 25 minutes'},
#  223: {'description': 'Frittata containing onions, zucchini, squash, red peppers, broccoli, and cauliflower'},
#  224: {'description': 'Miso soup containing seaweed and green onion'},
#  225: {'description': 'Acadian syrup cake with cinnamon'},
#  226: {'description': 'Quick soup with a variety of vegetables and made using vegetable stock'},
#  227: {'description': 'Mashed avocado that is soft and savory'},
#  228: {'description': 'Baked potato casserole made from red potatoes and chicken broth'},
#  229: {'description': 'Spaghetti noodles with beef meatballs'},
#  230: {'description': 'Fried rice with real crab meat, onions, spring onions and cucumber'},
#  231: {'description': 'Steak tacos with salsa verde and salsa roja'},
#  232: {'description': 'Dipping sauce for shrimp with cheese and seasoning'},
#  233: {'description': 'Cake made with apples, eggs, and flour'},
#  234: {'description': 'Very high-energy dark coffee with excessive amounts of caffeine'},
#  235: {'description': 'Salmon finger platter with cheese'},
#  236: {'description': 'Deep fried vegetables'},
#  237: {'description': 'Spaghetti using year round egg catsup noodles, made with sauce consisting of ground beef meat, bacon (pork) meat, cheddar cheese, parmesan, and tomatoes.'},
#  238: {'description': 'Milk chocolate eggs filled with caramel'},
#  239: {'description': 'Lobster tails with angel hair pasta'},
#  240: {'description': 'Seasoned crayfish tails and vegetables served on tortillas'},
#  241: {'description': 'No-fry karela crispies (bitter melon)'},
#  242: {'description': 'Roast turkey with plum sauce'},
#  243: {'description': 'Fish meat prepared with swiss cheese'},
#  244: {'description': 'Fruits that are sugar frosted'},
#  245: {'description': 'Cupcakes made with chocolate chips and chocolate frosting'},
#  246: {'description': 'Baked vegan gluten free granola bars with nuts and pumpkin'},
#  247: {'description': 'Soup made from onions, carrots, and celery ribs'},
#  248: {'description': 'Butter croissants'},
#  249: {'description': 'German-style potatoes with braised bockwurst sausages on a hard-cider cabbage bed'},
#  250: {'description': 'Assorted walnuts'},
#  251: {'description': 'Pink cupcakes with pink icing'},
#  252: {'description': 'Dipping sauce for vegetables with curry powder'},
#  253: {'description': 'Thai Tom Yum Soup - spicy and sour broth made from shrimp, fish sauce and lemongrass'},
#  254: {'description': 'Pork, onions, and sweet peppers in a spicy BBQ sauce'},
#  255: {'description': 'Easy stir fry with green beans, tomatoes, and eggs, with garlic clove, salt, and sugar added for flavour'},
#  256: {'description': 'Loaded potato salad that tastes creamy and savoury, made with sour cream and loaded with bacon'},
#  257: {'description': 'Strawberry smoothie with oats and flax made using low-fat milk'},
#  258: {'description': 'Vegetarian rice noodles with shiitake mushrooms, carrots, and vegetable sauce'},
#  259: {'description': 'Kosher pickles made from cucumber, dill, vinegar, and gralic cloves'},
#  260: {'description': 'Deep fried onion rings'},
#  261: {'description': 'Grilled mushrooms in foil packets'},
#  262: {'description': 'Spaghetti made from grated vegetables'},
#  263: {'description': 'Low calorie chocolate chip cookies'},
#  264: {'description': 'Beef croquettes recipe containing ground beef'},
#  265: {'description': 'Spaghetti with mushrooms, onion, green pepper, chicken breasts, and alfredo sauce'},
#  266: {'description': 'Chinese meatball soup with meatball from ground turkey and breadcrumbs'},
#  267: {'description': 'Fruit tart with peach slices and cream cheese'},
#  268: {'description': "Italian melted cheese pot made from mozzarella that's dipped with tomatoes, broccoli etc."},
#  269: {'description': 'Tangy, garlicky, and savory beef greek meatloaf'},
#  270: {'description': 'Healthier donuts made from whole wheat bread and honey with no processed sugar'},
#  271: {'description': 'Snack made with pita bread, parmesan cheese, and seasonings'},
#  272: {'description': 'Almonds coated with butter and salt'},
#  273: {'description': 'Pirozhki russian snacks: small yeast dough bun stuffed with duck confit and plums'},
#  274: {'description': 'Smoothie with orange juice, mango, papayas, pineapple, soy milk, and coconut'},
#  275: {'description': 'Strawberry granita dessert with rose water'},
#  276: {'description': 'Baked eggs with goat cheese (Paleo)'},
#  277: {'description': 'Cheese sandwich spread to be put on bread'},
#  278: {'description': 'Cheesy tuna salad made with three different types of cheese'},
#  279: {'description': 'No-meat meat pie containing onions and mushrooms'},
#  280: {'description': 'Soft French flatbread made of flour, eggs, milk, rum, and salt'},
#  281: {'description': 'Pancake recipe made with buckwheat flour, eggs and milk'},
#  282: {'description': 'Macaroni cooked with salt, pepper, cheddar cheese, butter, and skim milk'},
#  283: {'description': 'Drink made with milk, cream, pineapple chunks, and pineapple jelly'},
#  284: {'description': 'High protein chicken salad made with vegetables'},
#  285: {'description': 'Seasoned lamb meat marinade'},
#  286: {'description': 'Berry dinner salad - mixed greens with dried cranberries, sunflower seeds, avocados'},
#  287: {'description': 'Spicy tuna sushi'},
#  288: {'description': 'Soup with an assortment of cheese and vegetables'},
#  289: {'description': 'Soup with cheese stuffed potatoes, bacon, and spices'},
#  290: {'description': 'Platter filled with grilled vegetables. Vegetables on the platter: peppers, sweet, green, and salad'},
#  291: {'description': 'Cheddar cheese pasta pie with avocados, tomato sauce, and chipotle chili in adobo'},
#  292: {'description': 'Sandwiches made with cooked pork'},
#  293: {'description': 'Muffins made from flour, salt, powder, and butter'},
#  294: {'description': 'Salad that can lower the blood sugar level'},
#  295: {'description': 'Southern U.S.A styled chicken cooked by frying in a pan'},
#  296: {'description': 'Crunchy deep fried chicken breasts'},
#  297: {'description': 'Macarons made from peanut butter and chocolate'},
#  298: {'description': 'Dunkin donuts style coffee with granulated sugar'},
#  299: {'description': 'Spicy pork kebabs'},
#  300: {'description': 'Angel hair pasta with fresh parmesan cheese and butter'},
#  301: {'description': 'Zucchini dip made with tahini and red pepper flakes'},
#  302: {'description': 'Greek style meatball soup made from minced beef, egg, and rice'},
#  303: {'description': 'Chicken wings with buffalo flavouring'},
#  304: {'description': 'Soup made with beef bones, potatos, carrots and celery'},
#  305: {'description': 'Recipe for dessert crepes containing rum'},
#  306: {'description': 'Japanese ramen noodles with a soy sauce flavoured broth'},
#  307: {'description': 'A jar of peaches covered in peach wine and syrup'},
#  308: {'description': 'Savory dish from red kidney beans, rice, and ham bone'},
#  309: {'description': 'Sweet crepes with Cool Whip topping, chocolate, and almonds'},
#  310: {'description': 'KFC style cabbage, carrot, and onion coleslaw'},
#  311: {'description': 'Fat-free high fiber muffins'},
#  312: {'description': 'Cucumber and red onion salad containing sour cream'},
#  313: {'description': 'Cheese chicken made with chicken legs, eggs, cheese, and breading'},
#  314: {'description': 'High sugar sweet cookies'},
#  315: {'description': 'Creamy noodles with dill seasoning made with egg substitute'},
#  316: {'description': 'Vegan meat loaf made from vegetarian protein and vegetarian beef bouillon powder'},
#  317: {'description': 'Recipe for oven baked apple and blueberry pie'},
#  318: {'description': 'Beef brisket soup containing chili powder'},
#  319: {'description': '3-ingredient pizza with mozzarella topping'},
#  320: {'description': 'German casserole from potatoes, sauerkraut, and polish sausage'},
#  321: {'description': 'Summer meringue dessert made of strawberry and kiwi meringue'},
#  322: {'description': 'Smoothie made from fruit juice and bananas'},
#  323: {'description': 'Japanese rice ball containing tuna, wrapped with nori (seaweed)'},
#  324: {'description': 'Sweet dessert nachos with peanut butter, sugar, chocolate chips, marshmallows and coconut'},
#  325: {'description': 'Tangy beef meatballs containing Worcestershire sauce'},
#  326: {'description': 'Calcium-rich soup made with broccoli and beans'},
#  327: {'description': 'Sweet kiwi tart made from real kiwis'},
#  328: {'description': 'Muffin suitable for lunch containing zucchini, walnuts, and raisins'},
#  329: {'description': 'Balls made from sausage with seasoning'},
#  330: {'description': 'Rye bread made from active dry yeast'},
#  331: {'description': 'Corn dogs - hot dog on sticks covered in a cornmeal batter and deep fried'},
#  332: {'description': 'Sweet winter melon jam'},
#  333: {'description': 'Sweet moon cake made from lotus seeds and walnuts, eaten for Chinese mid autumn festival'},
#  334: {'description': 'Guacamole made from avocado and soft tofu'},
#  335: {'description': 'Spaghetti noodle recipe with bell peppers, meat, and tomato sauce'},
#  336: {'description': 'Slushie drink made from orange juice blended with ice'},
#  337: {'description': 'Subway broccoli soup made from chicken broth'},
#  338: {'description': 'Fish meat cooked on a grill / stovetop / oven'},
#  339: {'description': 'Dip for strawberries made from cream cheese and marshmellow creme'},
#  340: {'description': 'Stew made with chicken thighs, vegetables, and chicken broth'},
#  341: {'description': 'Spaghetti noodles with marinara sauce made with olive oil, garlic, tomatoes, salt, black pepper, basil, and parsley'},
#  342: {'description': 'Berry post workout smoothie containing fresh raspberries strawberries, blueberries, and banana'},
#  343: {'description': 'Simple potato bake with cheese, ham, sour cream, and onion'},
#  344: {'description': 'Fake steak made from seitan'},
#  345: {'description': 'Zucchini baked with onion, poppy seeds, and cheese'},
#  346: {'description': 'Banana bread made with whole wheat flour and walnuts'},
#  347: {'description': 'Nutella-swirled zucchini and carrot cake'},
#  348: {'description': 'Chocolate ice cream'},
#  349: {'description': 'Crackers with high fat cheese on top'},
#  350: {'description': 'Oven-roasted potatoes, carrots, and fresh green beans'},
#  351: {'description': 'A whole turkey for Thanksgiving'},
#  352: {'description': 'Spicy chicken made with chicken breasts and chicken thighs'},
#  353: {'description': 'Italian chicken made from chicken thighs. Flavoured with tomato paste'},
#  354: {'description': 'Soup made with chicken breast, chili powder, and chili beans'},
#  355: {'description': 'Paleo waffles made from eggs, butter, and coconut flour'},
#  356: {'description': '3-ingredient kale and peach salad with vinaigrette dressing'},
#  357: {'description': 'Sausages cooked in a beer sauce'},
#  358: {'description': 'Organic chocolate cupcakes'},
#  359: {'description': 'Fruit salad with peaches, blackberries, strawberries and lime'},
#  360: {'description': 'Nut-free banana bread containing sour cream'},
#  361: {'description': 'Chicken pieces that are deep fried'},
#  362: {'description': 'Meat cholent made with beef'},
#  363: {'description': 'Gluten-free apple and nut cake'},
#  364: {'description': 'Fried shrimp and scallops'},
#  365: {'description': 'Banana smoothie made of milk, nutritious for kids'},
#  366: {'description': 'Steamed sweet potato arranged with creme fraiche and caviar bites'},
#  367: {'description': 'Recipe for butterscotch brownie mix with high fat and pecans'},
#  368: {'description': 'Diced baked or fried potatoes'},
#  369: {'description': 'Classic egg sandwich - mashed eggs with mayonnaise sandwiched between white bread'},
#  370: {'description': 'Pan fried egg noodles with onion and green pepper'},
#  371: {'description': 'Low fat pancakes containing unsweetened apple sauce, skim milk, whole wheat flour, and sugar substitute'},
#  372: {'description': 'Green beans roasted with fresh ginger'},
#  373: {'description': 'Healthy korean soup made of chicken filled with garlic, rice, jujube, and ginseng'},
#  374: {'description': 'Sandwich spread made with apricot jam'},
#  375: {'description': 'Creamy hummus made from garbanzo beans'},
#  376: {'description': 'Pie with apples'},
#  377: {'description': 'Fresh pear and chocolate tart dessert'},
#  378: {'description': 'Smores dessert bars containing chocolate chips and marshmallow cream'},
#  379: {'description': 'Tasty and healthy diet food: chicken noodle goulash'},
#  380: {'description': 'Homemade soup with chicken, noodles, and spices'},
#  381: {'description': 'Fizzy lemon soda'},
#  382: {'description': 'Vanilla flavored ice cream made with eggs'},
#  383: {'description': 'Cheesy pizza soup made with premade tomato basil soup, pepperoni, pizza cheese, and fresh basil'},
#  384: {'description': 'Healthy lasagna made from ground beef, canned tomatoes, and cheese'},
#  385: {'description': 'Pizza made from soy flour, eggs and cream for low carb diet'},
#  386: {'description': 'Dessert containing yogurt, pudding mix, milk and three types of fruits'},
#  387: {'description': 'German sausage made from beef and ground pork'},
#  388: {'description': 'Hot and spicy ribs'},
#  389: {'description': 'Eggplant bolognese pasta containing ground meat'},
#  390: {'description': 'Boneless boston pork roasted and marinated for 6 hours'},
#  391: {'description': 'Marshmallow whip spread'},
#  392: {'description': 'Chili made from ground beef, tomatoes, kidney beans, and no peppers'},
#  393: {'description': 'Chocolate cake made from plain flour, cocoa powder, eggs, and milk'},
#  394: {'description': 'Soup made with peanut butter and milk'},
#  395: {'description': 'Indian style traditional flatbread'},
#  396: {'description': 'Oreo ice cream'},
#  397: {'description': 'Baked white chocolate cheesecake'},
#  398: {'description': 'Mille Feuilles - French confection that is made by layering pastry puff with vanilla cream.'},
#  399: {'description': 'Vanilla cream puffs'},
#  400: {'description': 'Guacamole made with avocados, fresh tomatoes, and cream cheese'},
#  401: {'description': 'Shrimp roasted with vegetables in a zesty Italian dressing'},
#  402: {'description': 'Chocolate dip made with chocolate chips and heavy cream'},
#  403: {'description': 'Fried home style chicken with outer layer made from flour, paired together with jasmine rice'},
#  404: {'description': 'Classic hot pumpkin spice latte'},
#  405: {'description': 'Bread soaked in french toast mix and cooked in the oven with diced apples'},
#  406: {'description': 'Burger made of ground chuck'},
#  407: {'description': 'Steak and ale pie - traditional British pie filled with beef and mushroom stew made with ale'},
#  408: {'description': 'Pumpkin gelato made from milk, heavy cream, sugar, cinnamon, and pumpkin puree'},
#  409: {'description': 'Sweet and sour beet polish soup full of vegetables'},
#  410: {'description': 'Deviled eggs'},
#  411: {'description': 'Tuna with onions and cooked rice'},
#  412: {'description': 'Blueberry crisp containing blueberries, brown rice, rice bran, and walnuts'},
#  413: {'description': 'Pina colada - cocktail made from coconut cream, pineapple juice and rum'},
#  414: {'description': 'Marshmallows on a stick decorated with assorted colourful candy'},
#  415: {'description': 'Gluten free nachos from corn flour'},
#  416: {'description': 'Gingersnaps - thin and brittle ginger cookies'},
#  417: {'description': "Sweet potato casserole that's mildly sweet"},
#  418: {'description': 'Spanish rice with chicken, spicy sausage, and seafood with low sugar content'},
#  419: {'description': 'Sushi topped with salmon roe and salmon sashimi'},
#  420: {'description': 'Scottish hot pot with beef, potatoes, and flavoured with tomato paste'},
#  421: {'description': 'Vegetable stir fry using chicken broth'},
#  422: {'description': 'Soup from chicken broth, mushroom, and leftover turkey'},
#  423: {'description': 'Classic French macarons containing orange flavouring'},
#  424: {'description': 'Gluten-free salted chocolate chip cookies'},
#  425: {'description': 'Low-calorie cherry and yogurt ice cream containing rum'},
#  426: {'description': 'Pork chops made with orange juice, garlic, and thyme'},
#  427: {'description': 'Kimchi - korean spicy fermented cabbage'},
#  428: {'description': 'Pizza topped with ham, onion, and mushrooms'},
#  429: {'description': 'Grilled sandwich made with vegetables and cheese'},
#  430: {'description': 'Chicken breasts stir-fried with peppers and rice'},
#  431: {'description': 'Meatballs made with a ground meat substitute'},
#  432: {'description': 'Spinach salad with bacon, green onions, and Worcestershire sauce'},
#  433: {'description': 'Mushy peas that are soft'},
#  434: {'description': 'Grilled cheese sandwich with four types of cheese'},
#  435: {'description': 'Meat loaf with beef, onions, peppers, tomatoes and quick-cooking oats'},
#  436: {'description': 'Stuffing made of pork and cornbread to be used for Thanksgiving'},
#  437: {'description': 'A German bread roll usually eaten in the morning'},
#  438: {'description': 'Italian sausage made with ground pork and various herbs and spices'},
#  439: {'description': 'Cherry flavoured coke made from coke and kool-aid'},
#  440: {'description': 'Chicken cooked on the BBQ with dry rub seasoning'},
#  441: {'description': 'Japanese curry rice made of only vegetables'},
#  442: {'description': 'Pasta salad with chicken meat, bacon, turkey, tomatoes, onions, and scallions'},
#  443: {'description': 'German chocolate cake mixed with ice cream sundae'},
#  444: {'description': 'Zesty sausage snacks made with cayenne pepper and worcestershire sauce'},
#  445: {'description': 'Creamy seafood chowder with onions and mushrooms'},
#  446: {'description': 'Banana pancakes made using waffle mix'},
#  447: {'description': 'Meringues flavoured with rose water'},
#  448: {'description': 'Fresh, simple pasta made without meat or animal byproducts'},
#  449: {'description': 'Noodles made with zucchini and topped with parmesan cheese'},
#  450: {'description': 'Pizza burger made with pizza sauce and cheese'},
#  451: {'description': 'Sweet purple cabbage coleslaw containing Miracle Whip'},
#  452: {'description': 'Blue punch made from blue kool aid, sprite and vanilla ice cream'},
#  453: {'description': 'Simple fried rice with carrots and peas'},
#  454: {'description': 'Vegetarian spring rolls with noodles'},
#  455: {'description': 'Classic strawberry shortcake - shortcake layered with strawberry slices and whipped cream'},
#  456: {'description': 'Milk chocolate eggs with cream-like filling'},
#  457: {'description': 'Pickled dill cucumbers'},
#  458: {'description': 'Crispy onion rings make with whole wheat flour, egg white, buttermilk, and onions'},
#  459: {'description': 'Cooked sweet potatoes with sweet and spicy taste'},
#  460: {'description': 'Appetizer of Peruvian style chicken soup with potatoes and bell pepper'},
#  461: {'description': 'Boston Cream filling made from sugar, lemon, tartaric, and egg whites'},
#  462: {'description': 'Harry Potter pumpkin pasties filled with pumpkin pie'},
#  463: {'description': 'Caesar salad made from romaine lettuce and croutons'},
#  464: {'description': 'Milkshakes made with lactose-free milk'},
#  465: {'description': 'Standard angel food cake - egg white based sponge cake'},
#  466: {'description': 'Korean soup containing beef brisket and flavoured with red pepper powder'},
#  467: {'description': 'Bitter herbs salad'},
#  468: {'description': 'Stir fry made from tomatoes and eggs, flavoured with scallions, garlic, and peanut oil'},
#  469: {'description': 'Tuna salad made with chunk tuna and cottage cheese'},
#  470: {'description': 'Grilled barbeque ribs'},
#  471: {'description': 'Korean style hot pot made with vegetables'},
#  472: {'description': 'Kielbasa sausage stew with potato, carrots and shrimp'},
#  473: {'description': 'Smoothie with yogurt and chocolate'},
#  474: {'description': 'Croissant sandwich made with vegetables'},
#  475: {'description': 'A no-bake pudding layered with vanilla wafer and bananas'},
#  476: {'description': 'Hearty cabbage soup also containing potatoes, celery, and onions'},
#  477: {'description': 'Chicken breasts stir-fried with onions, carrots, bell pepper, and peas'},
#  478: {'description': 'Beef paired with bacon entree'},
#  479: {'description': 'Orange dinner rolls made with flour, sugar, eggs, and orange zest'},
#  480: {'description': 'Filipino fried  wheat noodles with chicken and vegetables'},
#  481: {'description': 'European-style cheesecake with a graham cracker crust'},
#  482: {'description': 'Turkey meat tenderloins paired with bacon'},
#  483: {'description': 'Broiled(oven) chicken made with vegetables, beans, and seeds'},
#  484: {'description': 'Cherry cream cheese dip with cinnamon tortillas'},
#  485: {'description': 'Potato gnocchi stir-fried with cabbage and onions'},
#  486: {'description': 'Potatoes stuffed with caviar'},
#  487: {'description': 'Sundae made with fudge'},
#  488: {'description': 'Poke made from tuna with soy sauce seasoning'},
#  489: {'description': 'Sweet red bean paste that can be used as filling'},
#  490: {'description': 'Nuts made with almond and chili powder'},
#  491: {'description': 'Avocado and egg cracker snack with lemon and spices'},
#  492: {'description': 'Squash, kale, onion, and zucchini casserole with brown rice, low-sodium broth'},
#  493: {'description': 'Oats boiled in milk'},
#  494: {'description': 'Chocolate cream puffs made with heavy cream'},
#  495: {'description': 'Sticky rice wrapped pork shoulder for Chinese dragon boat festival'},
#  496: {'description': 'Vanilla cake decorated with Cool Whip and marshmallows to look like a lamb'},
#  497: {'description': 'High protein / energy content smoothie with blackberries, and greek yogurt'},
#  498: {'description': 'Side dish recipe for mushrooms'},
#  499: {'description': 'Poutine with spaghetti sauce and cheese curds'},
#  500: {'description': 'Savory French fish soup made of boneless fish fillet'},
#  501: {'description': 'Fried chicken breast halves and chicken legs'},
#  502: {'description': 'Chocolate ice milk sundaes topped with chocolate vanilla sauce'},
#  503: {'description': 'Low fat baked breakfast pie made with sausage (pork) and apples'},
#  504: {'description': 'Soup with chicken'},
#  505: {'description': 'Salad made with lettuce and tomatoes'},
#  506: {'description': 'Crispy potato pancakes with bacon.'},
#  507: {'description': 'Peking Duck - Chinese style crispy roast duck with hoisin sauce'},
#  508: {'description': 'French fries topped with Mexican chili with ground beef'},
#  509: {'description': 'Pie made with various kinds of seafood'},
#  510: {'description': 'Low-glycemic dessert made from apples and butter'},
#  511: {'description': 'Stir fried spicy korean rice cakes'},
#  512: {'description': 'Moist coconut cake with coconut frosting'},
#  513: {'description': 'Breakfast sausage made from scratch using pork shoulder'},
#  514: {'description': 'Low sugar applesauce cupcakes'},
#  515: {'description': 'Frozen butterbeer from cream soda and butterscotch'},
#  516: {'description': 'Chinese fried noodle with chicken breast and flavoured with garlic, spring onion, and ginger'},
#  517: {'description': 'Sweet potatoes with lemon juice'},
#  518: {'description': 'Soup made with organic carrots'},
#  519: {'description': 'Fluffy milk cake made from whole milk'},
#  520: {'description': 'Marinade for ribs'},
#  521: {'description': 'Pan-roasted lobsters'},
#  522: {'description': 'Corned beef with chili sauce'},
#  523: {'description': 'Rock candy (sugar crystals)'},
#  524: {'description': 'Spicy hotpot broth with Sichuan chili peppers'},
#  525: {'description': 'Caribbean dessert made of bananas, nutmeg, and brown sugar'},
#  526: {'description': 'Grilled seasoned bell peppers, carrots and snow peas in foil packets'},
#  527: {'description': 'Pot stickers stuffed from mushrooms and ground pork'},
#  528: {'description': 'High fiber kosher chocolate roll'},
#  529: {'description': 'Pancakes made with whole wheat flour and vegetable oil'},
#  530: {'description': 'Fried Egypt Ridge Catfish'},
#  531: {'description': 'Salad with banana slices and pecans'},
#  532: {'description': 'Chuck round steaks with green peppers'},
#  533: {'description': 'Jalapeno peppers that have been pickled by storing in seasoned liquid'},
#  534: {'description': 'Dessert made from rice krispies, fruit roll-ups, and gummy worms'},
#  535: {'description': 'Fragrant pilaf made from quinoa'},
#  536: {'description': 'Tomato soup with onions, parsley, and celery'},
#  537: {'description': 'Muffins made with fruit, yogurt, and without animal byproducts '},
#  538: {'description': 'Traditional savoury Tteokguk made with rice cake and beef for festivals'},
#  539: {'description': 'Sweet potato casserole with marshmallows and pecans'},
#  540: {'description': 'Assorted nuts mix containing pecans, cashews, and almonds'},
#  541: {'description': 'Crackers with cheese on top'},
#  542: {'description': 'Sandwiches made with shredded barbecued chicken thighs'},
#  543: {'description': 'Rum and coffee cream after dinner drink recipe'},
#  544: {'description': "Moist banana muffins that don't contain butter"},
#  545: {'description': 'Cucumber and plain yogurt salad'},
#  546: {'description': 'Mini muffins with mashed carrots and applesauce'},
#  547: {'description': 'Spanish style garlic shrimp'},
#  548: {'description': 'Spicy barbequed beef sandwich'},
#  549: {'description': 'low salt ranch dressing'},
#  550: {'description': 'Pita bread with falafel (deep fried ball made from chickpeas)'},
#  551: {'description': 'Chinese stir fried chicken with almonds'},
#  552: {'description': 'Creamy soup with chicken meat and cayenne pepper'},
#  553: {'description': 'Comfort food made from ground beef, celery, and mushrooms'},
#  554: {'description': 'Sausage, egg, and cheese breakfast taco recipe'},
#  555: {'description': 'A fluffy cocoa Swiss roll sponge recipe'},
#  556: {'description': 'Strong black Caribbean coffee with rum'},
#  557: {'description': 'Canadian coffee with whiskey and maple syrup'},
#  558: {'description': 'Poutine flavoured baked potatoes with cheese'},
#  559: {'description': 'Baby back ribs with soy sauce, sugar, garlic, honey, and ginger'},
#  560: {'description': 'Rosted turkey made for Thanksgiving'},
#  561: {'description': 'High protein pizza made with whole wheat pizza crusts, cheese, onions, and tofu'},
#  562: {'description': 'Apple pie made with apples, cinnamon, sugar, butter, and premade shell and crust'},
#  563: {'description': 'Vitamin-rich smoothies made with cranberries, carrot, mango, strawberries, and cantaloupe'},
#  564: {'description': 'Breakfast sausages and cream cheese wrapped in Crescent rolls'},
#  565: {'description': 'Sweet BBQ Beef Kabobs'},
#  566: {'description': 'Chocolate-flavoured French eclairs made from vanilla instant pudding mix'},
#  567: {'description': 'Slushie drink made from kool aid drink mix blended with ice'},
#  568: {'description': 'Pink macarons made from frozen strawberries'},
#  569: {'description': 'Recipe for baking pie with strawberries'},
#  570: {'description': 'Rotisserie style chicken cooked by slow cooking in a crockpot'},
#  571: {'description': 'Refreshing and cool peppermint and chocolate chip vegan dessert '},
#  572: {'description': 'Tacos with fish fillets and green chilies'},
#  573: {'description': 'Sweet candy made with candy canes, white chocolate chips, and candy sprinkles'},
#  574: {'description': 'Noodles made with butter and chives.'},
#  575: {'description': 'Tomato couscous with green beans, olives, parsley, and pinto beans'},
#  576: {'description': 'Grilled marinated spicy ribs with cayenne pepper.'},
#  577: {'description': 'Pork meat cooked with salsa verde, vegetables, nuts, and rice in a slow cooker'},
#  578: {'description': 'Fast and easy vegan-friendly pizza recipe'},
#  579: {'description': 'Seafood paella - sauteed saffron-flavoured rice cooked with seafood'},
#  580: {'description': 'Japanse mushroom soup from chicken stock'},
#  581: {'description': 'Bun stuffed with BBQ pork'},
#  582: {'description': 'Sushi filled with smoke salmon'},
#  583: {'description': 'Taco salad with vegetables'},
#  584: {'description': 'Kombucha - fermented and sweetened black tea drink'},
#  585: {'description': 'Assortment of shredded vegetables and berries with seasoning'},
#  586: {'description': 'Cookies and cream ice cream made with oreo cookies'},
#  587: {'description': 'German tart made of citrus fruits'},
#  588: {'description': 'Bananas blended with chocolate syrup'},
#  589: {'description': 'Instant ramen with eggs, spinach and pickled cabbage'},
#  590: {'description': 'Rice noodles with beef knuckle and oxtails'},
#  591: {'description': 'Fijian fish curry from fish, chilies, cumin, turmeric, and coconut milk'},
#  592: {'description': 'Pasta noodle salad with tuna and a variety of vegetables'},
#  593: {'description': 'Greasy chicken made with chicken thighs and soy sauces'},
#  594: {'description': 'Vegan burger made of beans and carrots'},
#  595: {'description': 'Meat loaf made with pork, onion, carrot, egg, meal, and breadcrumbs'},
#  596: {'description': 'Soup made with beef broth'},
#  597: {'description': 'A mixture of raw Mexican vegetables'},
#  598: {'description': 'Black tea sweetened with condensed milk'},
#  599: {'description': 'Easy chicken legs made with Italian salad dressing'},
#  600: {'description': 'Cake made from flour and eggs'},
#  601: {'description': 'Simple quinoa sprouts recipe only requiring distilled water'},
#  602: {'description': 'Spicy scallops cooked with sambal oelek chili paste'},
#  603: {'description': 'Soup made with ground beef, tomatoes, carrots, onions, spinach. Seasoned with: thyme, oregano, and garlic'},
#  604: {'description': 'Classic smores - marshmallows and chocolate sandwiched between graham crackers'},
#  605: {'description': 'Classic peppermint candy canes'},
#  606: {'description': 'Whole wheat spaghetti with a variety of vegetables: tomatoes, red onion, yellow bell pepper, red bell pepper, zucchini, fresh mushrooms'},
#  607: {'description': 'Vegan asian noodle salad'},
#  608: {'description': 'Fried bananas sprinkled with cinnamon'},
#  609: {'description': 'Weight-loss friendly eggnog that is sugar-free'},
#  610: {'description': 'Cucumber sauce with fat-free yogurt and reduced-fat mayonnaise'},
#  611: {'description': 'Bread made from scratch that contains dried cranberries and walnuts'},
#  612: {'description': 'Lime water with mint'},
#  613: {'description': 'Sausage, lunchmeat, and bacon breakfast cups'},
#  614: {'description': 'Breakfast bars made with eggs and flour'},
#  615: {'description': 'cake made with fruit cocktail'},
#  616: {'description': 'Stew made to resemble a hamburger, made with: beef, tomatoes,onions, potatoes, and carrots.'},
#  617: {'description': 'Noodles with chicken and eggs'},
#  618: {'description': 'Cheddar biscuits copying the ones at Red Lobster restaurant'},
#  619: {'description': 'Fried chicken meat and paired with a salad. Seasoned with cayenne pepper, garlic, and pepper'},
#  620: {'description': 'Italian salad made from romain lettuce, artichokes, and tomatoes'},
#  621: {'description': 'Creamy broccoli dish with mayonnaise and cheddar cheese'},
#  622: {'description': 'Chinese meat balls made from ground pork and water chestnut, with a side of bok choy'},
# ...
#  791: {'description': 'Dressing made with lemon juice,evaporated milk and avocado'},
#  792: {'description': 'Any cereal with milk'},
#  793: {'description': 'Sour bean, wheat, lentil, and swiss chard soup containing lemon juice'},
#  794: {'description': 'Jam made from blackberries, lemon juice, and sugar'},
#  795: {'description': 'Fortune cookie recipe from scratch made using egg whites'},
#  796: {'description': 'Crispy baked kale chips'},
#  797: {'description': 'Sandwich made with: grilled / broiled marinated chicken'},
#  798: {'description': 'Protein-packed cottage cheese pineapple snack'},
#  799: {'description': 'Classic sugar donuts'},
#  800: {'description': 'Chocolate chip cookies made with artificial sweetener and semi-sweet chocolate'},
#  801: {'description': 'Low fat potatoes cut and stuffed with cheese and cream of chicken and then cooked'},
#  802: {'description': 'Cheese with crackers'},
#  803: {'description': 'Smoothie with yogurt, chocolate, and oatmeal'},
#  804: {'description': 'Sauerkraut - German fermented cabbage'},
#  805: {'description': 'Ice cream made with fresh strawberries'},
#  806: {'description': 'Yellow rice made with rice cooker'},
#  807: {'description': 'Sweet heat chili with ground meat, vegetables, beans, and jalapeno peppers'},
#  808: {'description': 'Italian style sandwiches made with beef'},
#  809: {'description': 'Pan-fried pork noodles with chicken broth'},
#  810: {'description': 'Broiled flank steak seasoned with southern American spices'},
#  811: {'description': 'Seafood linguine recipe containing shrimp'},
#  812: {'description': 'Breaded fish fillets baked with parmesan cheese in the oven'},
#  813: {'description': 'White bread and butter pudding with whole milk and whipping cream'},
#  814: {'description': 'Caribbean style chicken with sauce made from soy sauce, pepper sauce, and lime juice'},
#  815: {'description': 'Bacon, lettuce, and tomato salad with buttermilk'},
#  816: {'description': 'Cookies made with peanuts'},
#  817: {'description': 'Smoothie made from banana puree with milk'},
#  818: {'description': 'Rice and shrimp stir fry with soy sauce and ground ginger for flavour'},
#  819: {'description': 'Quick mushroom, tomato, zucchini, and onion skewers'},
#  820: {'description': 'Soup made with shrimp, onions, and scallops'},
#  821: {'description': 'Casserole with corn kernels, bacon, and onions'},
#  822: {'description': 'Tortilla chips with melted cheese and chopped vegetables'},
#  823: {'description': 'Greasy lamb kebab'},
#  824: {'description': 'Low fat assorted green vegetables for snacking'},
#  825: {'description': "Harvey's Ranger cookies with raisins"},
#  826: {'description': 'Bitter compote made with orange and honey'},
#  827: {'description': 'Deep fried eggplants covered in batter'},
#  828: {'description': 'Easy to make refrigerated garlic fridge pickle'},
#  829: {'description': 'Szechuan-style spicy lo mein noodles with bell peppers'},
#  830: {'description': 'Pepper steak dish with spices and paired with sauce'},
#  831: {'description': "Mexican s'mores made from chocolate and peanut butter"},
#  832: {'description': 'Carrot soup that contains onions, curry seasoning, cream, and butter'},
#  833: {'description': 'Dandan noodles made with ground beef and chinese sesame paste'},
#  834: {'description': 'Quick pho made with sliced beef'},
#  835: {'description': 'Keto friendly sandwich made with meat, cucumber, and cheese'},
#  836: {'description': 'Fruit pie with apples, peaches, blackberries, strawberries, and rhubarb'},
#  837: {'description': 'Pasta salad containing celery, pineapple, ham, and corn'},
#  838: {'description': 'Hot dogs with hot pepper sauce and green chillies'},
#  839: {'description': 'Tomato-based pasta and bean soup with bacon and vegetables'},
#  840: {'description': 'Beef wellington with Foie Gras'},
#  841: {'description': 'Nabemono - traditional Japanese hotpot with a broth that has a dashi and chicken base'},
#  842: {'description': 'Tuna tataki - lightly seared tuna steaks in ponzu sauce'},
#  843: {'description': 'Potatoes cut and stuffed with cheese and then cooked'},
#  844: {'description': 'Chinese pot roast made from beef and served with cabbage'},
#  845: {'description': 'Low fat apple and butternut squash soup made with light cheddar cheese'},
#  846: {'description': 'Pear liquor made with pears and vodka'},
#  847: {'description': 'Popeyes biscuits made from biscuit mix, sour cream, and club soda'},
#  848: {'description': 'Kenyan fresh tomato and onion salad'},
#  849: {'description': 'Poke of tofu, mushroom and tomatoes'},
#  850: {'description': 'Thinly sliced beef rolled into appetizer sized rolls'},
#  851: {'description': 'Platter filled with vegetables'},
#  852: {'description': 'Cod fillets and fries dipped in low fat mayonnaise'},
#  853: {'description': 'Tomato mussel soup containing dry white wine'},
#  854: {'description': 'Passionfruit punch made from real passionfruit'},
#  855: {'description': 'Grilled salmon fillets with hoisin sauce and soy sauce in foil packets'},
#  856: {'description': 'Fresh pineapple mixed with chili peppers, sugar, and coarse salt'},
#  857: {'description': 'Treats for dogs that contain milk'},
#  858: {'description': 'Salmon roasted with olive oil, chives, and tarragon leaves'},
#  859: {'description': 'Brussel sprout slaw made with a variety of sauces and seasonings, pecans, and pomegranate seeds'},
#  860: {'description': 'Creamy avocado dip for chips'},
#  861: {'description': 'Carrot ice cream made with carrots, cornstarch, whole milk, and light cream'},
#  862: {'description': 'Clam chowder made with heavy whipping cream'},
#  863: {'description': 'Healthy coleslaw side dish made from cabbage'},
#  864: {'description': 'Seasoned mashed cauliflower with fromage frais'},
#  865: {'description': 'Nutritious meal made with sweet potato slices and ham'},
#  866: {'description': 'Chicken breasts cooked with kluski noodles'},
#  867: {'description': 'Catfish marinade'},
#  868: {'description': 'Meatloaf made with ground beef meat, sauce made with salsa, ready-to-serve delallo, italian seasoned breadcrumbs, and salsa'},
#  869: {'description': 'Salad made from broccoli, cauliflower, carrots, and sunflower seeds'},
#  870: {'description': 'Savory soup made from miso and red onions'},
#  871: {'description': 'Russian caramel fudge made from sweetened milk, golden syrup, and butter'},
#  872: {'description': 'Starbucks caramel scones containing butterscotch chips'},
#  873: {'description': 'Light and fluffy Russian milk souffle candy covered with white candy melt'},
#  874: {'description': 'Steak chipotle burrito with basmati rice and beans'},
#  875: {'description': 'Vegetable soup with ground beef'},
#  876: {'description': 'Jello shots with Vodka'},
#  877: {'description': 'Recipe for oven baked apple or blueberry pie (apples and blueberries are interchangeable)'},
#  878: {'description': 'A simple pasta with a drizzle of parmesan cheese'},
#  879: {'description': 'Coconut flavored rum beverage'},
#  880: {'description': 'Sweet potatoes seasoned with ginger'},
#  881: {'description': 'Cocoa flavoured churros'},
#  882: {'description': 'Easy-to-make cake made with Asian pears'},
#  883: {'description': 'Crunchy tacos with meat for dinner'},
#  884: {'description': 'Cookies with a jam filling'},
#  885: {'description': 'Shrimp with chili sauce and crushed red pepper flakes'},
#  886: {'description': 'Chicken breast fajita tortilla wraps'},
#  887: {'description': 'Tortilla wrap with sun-dried tomatoes, spinach, olives and cream cheese'},
#  888: {'description': "Grandma's apple cake with cinnamon"},
#  889: {'description': 'Savoury french toast with bacon, tomato and cheese'},
#  890: {'description': 'Abalone soup made with abalone, water, salt, bacon, onion, potatoes, parsley, milk, butter, crackers'},
#  891: {'description': 'Beef rib roast made with black peppercorns'},
#  892: {'description': 'Weight loss tea made with carrots and plums'},
#  893: {'description': 'Blueberry banana smoothie'},
#  894: {'description': 'Whole grain gluten-free spinach and soy bread'},
#  895: {'description': 'Banana pudding made with instant pudding mix'},
#  896: {'description': 'Halal marshmallow peanut popcorn bars with maple syrup'},
#  897: {'description': 'Barbecued Alaskan salmon'},
#  898: {'description': 'Dipping sauce for salmon with cheese and seasoning'},
#  899: {'description': 'Pizza with mozzarella cheese and pepperoni'},
#  900: {'description': 'Diabetes-friendly soup made with pumpkin and vegetable broth'},
#  901: {'description': 'Classic vanilla milkshake'},
#  902: {'description': 'Roasted soy beans with soy sauce'},
#  903: {'description': 'Fast and healthy cauliflower soup'},
#  904: {'description': 'Traditional chicken soup'},
#  905: {'description': 'Hearty potato soup containing onions, potatoes, celery and turkey bacon'},
#  906: {'description': 'Baked chicken drumsticks in tomato sauce'},
#  907: {'description': 'Creamy mushroom soup'},
#  908: {'description': 'Grilled pork spare ribs'},
#  909: {'description': 'Chocolate cupcakes made with flour, sugar, and cocoa'},
#  910: {'description': 'Pepperoni stick made from ground beef'},
#  911: {'description': 'Jam made from lemon juice, sugar, and fresh strawberries'},
#  912: {'description': 'Deluxe burger made from ground sirloin'},
#  913: {'description': 'Whole-wheat pasta with chicken and pesto sauce'},
#  914: {'description': 'Baked asparagus casserole dish with Worcestershire sauce'},
#  915: {'description': 'Low fat / cholesterol imitation egg recipe without animal byproducts or meat'},
#  916: {'description': 'Noodles stir-fried with cabbage, sliced mushrooms, carrots, green beans, ham'},
#  917: {'description': 'Acadian style chicken stew'},
#  918: {'description': 'German puffed up breakfast pancake from eggs, milk, and flour'},
#  919: {'description': 'Roasted turkey breast with hummus and herbs'},
#  920: {'description': 'Creamy base with dill flavoring, eggs, and noodles'},
#  921: {'description': 'Mixed sausages braised in sauerkraut, hard cider, apples and onions along with bacon, green cabbage, and pumpernickel bread'},
#  922: {'description': 'Baked Kale with cheese on top'},
#  923: {'description': 'Baked spinach quiche containing bacon'},
#  924: {'description': 'Fried rice with sriracha and SPAM'},
#  925: {'description': 'Simple grilled cubed beef steaks with potatoes'},
#  926: {'description': 'Nut-free cookies without baking'},
#  927: {'description': 'Crackers with cheddar cheese on top'},
#  928: {'description': 'Harry Potter chocolate flavoured cauldron cake with marshmallows'},
#  929: {'description': 'Chicken fat for cooking with ramen'},
#  930: {'description': 'Fish meat cooked in a steamer'},
#  931: {'description': 'Microwave chocolate cake in a mug'},
#  932: {'description': 'Fluffy cake made with vanilla flavour'},
#  933: {'description': 'Shakshuka - Middle eastern dish of eggs poached in a sauce of tomatoes, olive oil, peppers, onion and garlic'},
#  934: {'description': "Light and fluffy Kenyan donuts that's usually served for breakfast with chai tea"},
#  935: {'description': 'Oven style cabbage with butter, bacon, salt, and pepper'},
#  936: {'description': 'Dish of avocados filled with fish mixture and egg whites from West Africa'},
#  937: {'description': 'Oven cooked thin pork meat with orange and maple flavoring'},
#  938: {'description': 'Yogurt smoothie made with low-fat yogurt, cool-whip, and strawberries'},
#  939: {'description': 'Passion fruit flavored alcoholic beverage'},
#  940: {'description': 'Cranberry punch'},
#  941: {'description': 'Vegan chili made from veggie griller grounds, kidney beans, and chili powder'},
#  942: {'description': 'Creamy clam chowder made with whole milk and baby clams'},
#  943: {'description': 'Pecan halves roasted with butter and salt'},
#  944: {'description': 'Soup made with ground turkey that is low fat, high carb'},
#  945: {'description': 'Banana cream pie made with low-fat graham crackers and nonfat milk'},
#  946: {'description': 'Deep fried mac and cheese with quinoa'},
#  947: {'description': 'High energy / mineral rich cranberry flavored juice'},
#  948: {'description': 'Sweet cinnamon roll made from frozen bread dough'},
#  949: {'description': 'Strawberry frozen yogurt made from plain yogurt'},
#  950: {'description': 'Basic oven cooked fries'},
#  951: {'description': 'Carrots, tomatoes, pepper, onions, and spinach vegetable balls for kids'},
#  952: {'description': 'Baked casserole made from macaroni, turkey, sausage, bacon, potato and low-fat cheese'},
#  953: {'description': 'Shrimp, scallops, brown rice, and vegetables with Jarlsberg cheese'},
#  954: {'description': 'Indian-style beef curry with coconut milk'},
#  955: {'description': 'Caviar dip from caviar and sour cream, nestled in ice'},
#  956: {'description': 'Lemon flavored icing'},
#  957: {'description': 'Chicken meat cooked in greek style with spices and herbs'},
#  958: {'description': 'Pulled pork sandwich with bbq sauce'},
#  959: {'description': 'Cheddar cheese and cracker bites'},
#  960: {'description': 'Mongolian hot pot with lamb and napa cabbage'},
#  961: {'description': 'Asian BBQ pork loin from boneless pork loin roast'},
#  962: {'description': 'Roast beef with peas and potatoes'},
#  963: {'description': 'Baked breakfast bars made with nuts and seeds'},
#  964: {'description': 'Vegan chili made from pinto beans, navy beans, and vegetable broth'},
#  965: {'description': 'Roasted cauliflower with olive oil and seasonings'},
#  966: {'description': 'Chicken soup with onions, carrots, parsnip, and celery made from scratch using a whole chicken'},
#  967: {'description': 'Baked chicken coated in swiss cheese'},
#  968: {'description': 'Brown rice paella containing mussels and Spanish chorizo that cooks fast'},
#  969: {'description': 'Orange, lemon, pineapple, strawberry fruit punch with sprite'},
#  970: {'description': 'Popeyes fried chicken with outer layer made from flour, then fried and sprinkled with pepper and paprika'},
#  971: {'description': 'Bacon with Little Smokies sausages and brown sugar'},
#  972: {'description': 'Spicy broccoli made with broccoli and green chili pepper'},
#  973: {'description': 'Asian bolognese made of ground chicken, tofu, and tomatoes with jasmine rice'},
#  974: {'description': 'Chocolate cream pie made with heavy cream and three types of chocolate'},
#  975: {'description': 'Shredded barbecued pork shoulder'},
#  976: {'description': 'Cold mushrooms on spinach with sauces and seasonings'},
#  977: {'description': 'Pickled carrots, cauliflower, and cucumbers'},
#  978: {'description': 'Penne with cheddar, gruyere, and cheese sauce'},
#  979: {'description': 'Rolled omelet with SPAM'},
#  980: {'description': 'Classic Chinese Sweet and Sour Pork'},
#  981: {'description': 'Savory cheese tart with bacon and eggs'},
#  982: {'description': 'Crispy chicken tacos with avocados and red onions'},
#  983: {'description': 'Classic gingerbread house'},
#  984: {'description': 'German breakfast from bacon, ham, fried potatoes, eggs, onions'},
#  985: {'description': 'Oven cooked chicken meat seasoned with paprika'},
#  986: {'description': 'Pie filled with bulk sausage, potatoes, onions, and carrots'},
#  987: {'description': 'White chocolate and pumpkin spice ice cream'},
#  988: {'description': 'Pizza with avocado and cheese'},
#  989: {'description': 'Chicken breasts stuffed with bacon and mozzarella'},
#  990: {'description': 'Vegetable based potato pancakes'},
#  991: {'description': 'A filling dish made made with beef and potatoes'},
#  992: {'description': 'Protein burger containing onions, tomatoes, ground beef, and flax seeds'},
#  993: {'description': 'Refreshing drink made of carrot juice, applesauce, yogurt, lemon juice, and fresh ginger'},
#  994: {'description': 'Ice cream with sugar, cream, egg yolks, and pistachios'},
#  995: {'description': 'Gluten-free chicken rice-a-roni dinner'},
#  996: {'description': 'Spaghetti pasta with beef bolognese sauce'},
#  997: {'description': 'Mexican pizza made with beans and ground beef'},
#  998: {'description': 'Brown basmati rice'},
#  999: {'description': 'Gluten, dairy, egg and soy-free dinner made with roasted vegetables'}}

# %%
# Save 1000 random items to file
save_file_1000_items = "data/recipe_1000_sample.json"
with open(save_file_1000_items, "w") as save_file:
    json.dump(items_1000_dict, save_file, indent=4)

# %% [markdown]
# ## 100 items

# %%
# Randomly select 100 items
np.random.seed(42)
keep_indices = list(np.random.choice(range(len(base_data)), size=(100,), replace=False))
items_100_dict = {}
for i in range(100):
    item_data = base_data[keep_indices[i]]
    items_100_dict[i] = {'description': item_data['options'][item_data['answer']]}
items_100_dict
# Out:
# {0: {'description': 'Soup made with cabbage, carrots, potatoes, and onions'},
#  1: {'description': '2-ingredient yogurt from scratch'},
#  2: {'description': 'High protein skillet with rice and vegetables'},
#  3: {'description': 'Chinese salad made of eggplant and zucchini, flavoured with soy sauce'},
#  4: {'description': 'Large portion fries with gravy and bacon'},
#  5: {'description': 'Beef stew made with beef, carrots and potatoes'},
#  6: {'description': 'Grilled salmon seasoned with salt and pepper'},
#  7: {'description': 'Poke of tofu, mushroom and tomatoes'},
#  8: {'description': 'Queso made from melted cheese and chili peppers'},
#  9: {'description': 'Low fat baked breakfast pie made with sausage (pork) and apples'},
#  10: {'description': 'Chicken breasts stuffed with bacon and mozzarella'},
#  11: {'description': 'Chopped French duck confit preserved by duck oil'},
#  12: {'description': 'Spaghetti using year round egg catsup noodles, made with sauce consisting of ground beef meat, bacon (pork) meat, cheddar cheese, parmesan, and tomatoes.'},
#  13: {'description': 'Smoothie made from fruit juice and bananas'},
#  14: {'description': 'Low sugar applesauce cupcakes'},
#  15: {'description': 'Soup made with ground turkey that is low fat, high carb'},
#  16: {'description': 'Creamy base with dill flavoring, eggs, and noodles'},
#  17: {'description': 'Garlic bread with cheddar, green onions, and mayonnaise'},
#  18: {'description': 'Soup made with shrimp, onions, and scallops'},
#  19: {'description': 'Meatloaf made with ground beef meat, sauce made with salsa, ready-to-serve delallo, italian seasoned breadcrumbs, and salsa'},
#  20: {'description': 'Low fat sweet potato fries made with cajun seasoning'},
#  21: {'description': 'Very low-fat assortment of shredded vegetables with seasoning'},
#  22: {'description': 'Dog food made from pork, green beans, cheddar cheese and brown rice'},
#  23: {'description': 'Sugar-free peanut butter cookies'},
#  24: {'description': 'Jam made from blackberries, lemon juice, and sugar'},
#  25: {'description': 'Noodles made with egg with a mixture of turkey, bacon, chicken broth, and seasoned'},
#  26: {'description': 'Mildly spicy chili recipe'},
#  27: {'description': 'Baked pumpkin dessert pie filled with a sweet pumpkin spice based custard'},
#  28: {'description': 'South African vegetable curry flavoured with curry powder and ground tumeric'},
#  29: {'description': 'Baked breakfast bars made with nuts and seeds'},
#  30: {'description': 'Assorted cheese soup with chicken'},
#  31: {'description': 'High protein pizza made with whole wheat pizza crusts, cheese, onions, and tofu'},
#  32: {'description': 'Cheese and olive appetizer made to look like an eyeball'},
#  33: {'description': 'Bread made swiss style with swiss cheese'},
#  34: {'description': 'Salmon fillets grilled in a pan with herbs and spices'},
#  35: {'description': 'Soup made from onions, carrots, and celery ribs'},
#  36: {'description': 'Sandwich made with: grilled / broiled marinated chicken'},
#  37: {'description': 'Chocolate and orange-flavoured smoothie'},
#  38: {'description': 'Slushie drink made from orange juice blended with ice'},
#  39: {'description': 'Cheesecake made with cream cheese'},
#  40: {'description': 'Fried shrimp and scallops'},
#  41: {'description': 'Pork cooked with onions, peppers, pineapple chunks, ketchup, karo syrup, and cider vinegar'},
#  42: {'description': 'Salmon roasted with olive oil, chives, and tarragon leaves'},
#  43: {'description': 'Norway cake with lingonberry and whipped cream layers'},
#  44: {'description': 'Spaghetti noodles with mussels, anchovy fillets, and capers'},
#  45: {'description': 'Apple pie made with apples, cinnamon, sugar, butter, and premade shell and crust'},
#  46: {'description': 'Simple creamy oyster soup'},
#  47: {'description': 'Shredded barbecued pork shoulder'},
#  48: {'description': 'Ramen noodles made from scratch made with: wheat flour, baking soda, and water'},
#  49: {'description': 'Beef chili containing jalapeno pepper, chili powder, cayenne pepper, and ground chipotle chile pepper'},
#  50: {'description': 'Oreo pie made with oreo cookies, butter, milk, and a tub of Cool Whip'},
#  51: {'description': 'Italian salad made from romain lettuce, artichokes, and tomatoes'},
#  52: {'description': 'Subway-style sandwich made from french baguette bread, ham, lettuce, and tomatoes'},
#  53: {'description': 'Low fat smoothies made with greek yogurt, and pineapple'},
#  54: {'description': 'French chocolate cake made from chocolate baking squares, strong coffee, butter, and brown sugar'},
#  55: {'description': 'Baked spinach quiche containing bacon'},
#  56: {'description': 'Sticky rice wrapped pork shoulder for Chinese dragon boat festival'},
#  57: {'description': 'Beef lasagna with whole wheat noodles, low-fat cottage cheese, and part-skim mozzarella cheese'},
#  58: {'description': 'Peppermint chocolate bonbon'},
#  59: {'description': 'Peach cobbler dessert containing whole wheat flour'},
#  60: {'description': 'Pork chops glazed with milk and cooked without nuts'},
#  61: {'description': 'Classic salad with creamy caesar dressing and croutons'},
#  62: {'description': 'Soup made with vegetables and chicken'},
#  63: {'description': 'Chicken cooked and flavored with lemon sauce'},
#  64: {'description': 'Berry cobbler that uses frozen mixed berries'},
#  65: {'description': 'Sweet salad made with corn and three types of beans'},
#  66: {'description': 'Breakfast egg, bean, and cheese burrito with jalapeno peppers'},
#  67: {'description': 'Caesar salad with cooked chicken, lettuce, tomatoes, croutons, and cheese'},
#  68: {'description': 'Roast turkey with plum sauce'},
#  69: {'description': 'Calcium-rich soup made with broccoli and beans'},
#  70: {'description': 'Gluten-free, egg-free, dairy-free, nut-free fudge'},
#  71: {'description': 'Almonds coated with butter and salt'},
#  72: {'description': 'Grilled squash, zucchinis, tomatoes and mushrooms seasoned with balsamic vinegar and herbs'},
#  73: {'description': 'Taiwanese deep fried crispy chicken cutlets'},
#  74: {'description': 'Roast beef sandwich with mozzarella, banana pepper rings and romaine lettuce'},
#  75: {'description': 'Milkshake made with fresh strawberries and ice cream'},
#  76: {'description': 'Cheese with crackers'},
#  77: {'description': 'Spaghetti with mushrooms, onion, green pepper, chicken breasts, and alfredo sauce'},
#  78: {'description': 'Low fat diced baked or fried potatoes'},
#  79: {'description': 'Low-fat coconut alcohol-free cocktail'},
#  80: {'description': 'Korean soup containing beef brisket and flavoured with red pepper powder'},
#  81: {'description': 'Salad made from 5 fruits: oranges, strawberries, blackberries, grapes, and pears'},
#  82: {'description': 'Cheese and vegetable soup with a beer broth'},
#  83: {'description': 'Polish sausage with fermented cabbage'},
#  84: {'description': 'Digestion-friendly waffles'},
#  85: {'description': 'Lemon loaf made with flour, baking powder, salt, shortening, sugar, eggs, lemons, milk'},
#  86: {'description': 'Spanish rice with chicken breast'},
#  87: {'description': 'Vegan macaroni pasta with frozen peas, olive oil, nutritional yeast, and seasoning'},
#  88: {'description': 'Stir-fried tofu, noodles and vegetables Bento'},
#  89: {'description': 'Roasted almonds'},
#  90: {'description': 'Hot pot that is not spicy'},
#  91: {'description': 'Homemade soup with chicken, noodles, and spices'},
#  92: {'description': 'Mushy peas that are soft'},
#  93: {'description': 'Smoothie made from banana puree with milk'},
#  94: {'description': 'Low fat assorted fruit dessert'},
#  95: {'description': 'Eggless sauerkraut cake'},
#  96: {'description': 'Banana bread made with whole wheat flour and walnuts'},
#  97: {'description': 'Baked mozzarella cheese sticks with marinara sauce'},
#  98: {'description': 'Mozzarella dip recipe'},
#  99: {'description': 'Meatballs made with ground beef and ground pork'}}

# %%
# Save 100 random items to file
save_file_100_items = "data/recipe_100_sample.json"
with open(save_file_100_items, "w") as save_file:
    json.dump(items_100_dict, save_file, indent=4)

# %% [markdown]
# ### 25 item non-overlapping set

# %%
full_idxs = []
for i in range(len(base_data)):
    full_idxs.append(i)
holdout_idxs = [idx for idx in full_idxs if idx not in keep_indices]

# %%
# Random 25 item sample from holdouts
np.random.seed(42)
fs25_temp_indices = list(np.random.choice(range(len(holdout_idxs)), size=(25,), replace=False)) # this is the idx of the idx of the item

# %%
fs25_temp_indices
# Out:
# [209,
#  280,
#  33,
#  210,
#  93,
#  84,
#  329,
#  94,
#  266,
#  126,
#  9,
#  361,
#  56,
#  72,
#  132,
#  42,
#  278,
#  376,
#  231,
#  385,
#  77,
#  15,
#  391,
#  271,
#  0]

# %%
fs25_items = {}
for i,fs_idx in enumerate(fs25_temp_indices):
    item_data = base_data[holdout_idxs[fs_idx]]
    fs25_items[i] = {'description': item_data['options'][item_data['answer']]}

# %%
fs25_items
# Out:
# {0: {'description': 'Mini corndogs'},
#  1: {'description': 'Flourless chocolate cake with butter'},
#  2: {'description': 'Creamy broccoli dish with mayonnaise and cheddar cheese'},
#  3: {'description': 'Chocolate cupcakes with blue vanilla custard filling hidden inside the cupcake'},
#  4: {'description': 'Loaded potato salad made with mayonnaise, buttermilk, cheddar and crumbled bacon'},
#  5: {'description': 'Chowder soup made from corn, bacon, cornstarch and heavy cream'},
#  6: {'description': 'Salmon cooked in the oven, seasoned with garlic, onion, cumin, dill, and lime'},
#  7: {'description': 'McDonalds-style fries made from russet potatoes'},
#  8: {'description': 'Protein box made from eggs, fruit, and yogurt'},
#  9: {'description': 'Sweet chinese red bean bun'},
#  10: {'description': 'Garlic butter strip steaks cooked with onions'},
#  11: {'description': 'Breakfast quiche with onions, swiss cheese, and bacon'},
#  12: {'description': '3-ingredient pizza with mozzarella topping'},
#  13: {'description': 'An Egyptian fruit cup made of dates and fruits'},
#  14: {'description': 'Thai curry with shrimp and coconut milk that can be dipped with bread'},
#  15: {'description': 'Salsa made with pineapple, mangoes, onions, black beans, corn, strawberries, jalapeno, and tomatoes'},
#  16: {'description': 'Ice cream with sugar, cream, egg yolks, and pistachios'},
#  17: {'description': 'Low sugar strawberry flavored slushie alcoholic cocktail'},
#  18: {'description': 'A Mexican take of traditional Filipino Adobo chicken with noodles'},
#  19: {'description': 'Spicy shrimp and tomato flavored soup'},
#  20: {'description': 'Caviar dip from caviar and sour cream, nestled in ice'},
#  21: {'description': 'Chinese-style steamed pork meatloaf'},
#  22: {'description': 'Cod cooked by roasting with seasoning'},
#  23: {'description': 'Spaghetti made from grated vegetables'},
#  24: {'description': 'Salmon roasted with olive oil, chives, and tarragon leaves'}}

# %%
# Save 25 random holdout items to file
save_file_fs_items = "data/FS_recipe_25_sample.json"
with open(save_file_fs_items, "w") as save_file:
    json.dump(fs25_items, save_file, indent=4)

# %% [markdown]
# ### 16 item subset

# %%
items_16_dict = {}
for i in range(16):
    items_16_dict[i] = items_100_dict[i]

# %%
items_16_dict
# Out:
# {0: {'description': 'Soup made with cabbage, carrots, potatoes, and onions'},
#  1: {'description': '2-ingredient yogurt from scratch'},
#  2: {'description': 'High protein skillet with rice and vegetables'},
#  3: {'description': 'Chinese salad made of eggplant and zucchini, flavoured with soy sauce'},
#  4: {'description': 'Large portion fries with gravy and bacon'},
#  5: {'description': 'Beef stew made with beef, carrots and potatoes'},
#  6: {'description': 'Grilled salmon seasoned with salt and pepper'},
#  7: {'description': 'Poke of tofu, mushroom and tomatoes'},
#  8: {'description': 'Queso made from melted cheese and chili peppers'},
#  9: {'description': 'Low fat baked breakfast pie made with sausage (pork) and apples'},
#  10: {'description': 'Chicken breasts stuffed with bacon and mozzarella'},
#  11: {'description': 'Chopped French duck confit preserved by duck oil'},
#  12: {'description': 'Spaghetti using year round egg catsup noodles, made with sauce consisting of ground beef meat, bacon (pork) meat, cheddar cheese, parmesan, and tomatoes.'},
#  13: {'description': 'Smoothie made from fruit juice and bananas'},
#  14: {'description': 'Low sugar applesauce cupcakes'},
#  15: {'description': 'Soup made with ground turkey that is low fat, high carb'}}

# %%
# Save 16 subset of 100 random items to file
save_file_16_items = "data/recipe_16_sample.json"
with open(save_file_16_items, "w") as save_file:
    json.dump(items_16_dict, save_file, indent=4)

# %%
# Create name to id map
inv_map = {v['description']: k for k, v in items_100_dict.items()}

# %%
# Save map to file
save_file_recipe_map = "data/name_maps/recipe_100_map.json"
with open(save_file_recipe_map, "w") as save_file:
    json.dump(inv_map, save_file, indent=4)

# %% [markdown]
# ### Testing for parsing

# %%
import re

# Your input string
dataset = [
            "Soup made with cabbage, carrots, potatoes, and onions \\n\n2-ingredient yogurt from scratch \\n\nHigh protein skillet with rice and vegetables \\n\nChinese salad made of eggplant and zucchini, flavoured with soy sauce \\n\nLarge portion fries with gravy and bacon \\n\nBeef stew made with beef, carrots and potatoes \\n\nPoke of tofu, mushroom and tomatoes \\n\nQueso made from melted cheese and chili peppers \\n\nLow fat baked breakfast pie made with sausage (pork) and apples \\n\nChicken breasts stuffed with bacon and mozzarella",
            "Beef stew made with beef, carrots and potatoes\nGrilled salmon seasoned with salt and pepper\nChicken breasts stuffed with bacon and mozzarella\nChopped French duck confit preserved by duck oil\nSpaghetti using year round egg catsup noodles, made with sauce consisting of ground beef meat, bacon (pork) meat, cheddar cheese, parmesan, and tomatoes.\nLow fat baked breakfast pie made with sausage (pork) and apples\nHigh protein skillet with rice and vegetables\nSoup made with ground turkey that is low fat, high carb\nChinese salad made of eggplant and zucchini, flavoured with soy sauce\nPoke of tofu, mushroom and tomatoes",
            "Chicken breasts stuffed with bacon and mozzarella\n****\nBeef stew made with beef, carrots and potatoes\n****\nHigh protein skillet with rice and vegetables\n****\nLow fat baked breakfast pie made with sausage (pork) and apples\n****\nChopped French duck confit preserved by duck oil\n****\nSpaghetti using year round egg catsup noodles, made with sauce consisting of ground beef meat, bacon (pork) meat, cheddar cheese, parmesan, and tomatoes.\n****\nSoup made with ground turkey that is low fat, high carb\n****\nChinese salad made of eggplant and zucchini, flavoured with soy sauce\n****\nPoke of tofu, mushroom and tomatoes\n****\nQueso made from melted cheese and chili peppers"
]

for data in dataset:
    # Splitting the string using regular expression
    # The pattern '\n\*{4}\n|\n' matches both '\n****\n' and '\n'
    recipes = re.split(r'\n\*{4}\n|\n|\\n\n', data)

    # Printing the list of strings
    for recipe in recipes:
        print(recipe)
# Out:
# Soup made with cabbage, carrots, potatoes, and onions
# 2-ingredient yogurt from scratch
# High protein skillet with rice and vegetables
# Chinese salad made of eggplant and zucchini, flavoured with soy sauce
# Large portion fries with gravy and bacon
# Beef stew made with beef, carrots and potatoes
# Poke of tofu, mushroom and tomatoes
# Queso made from melted cheese and chili peppers
# Low fat baked breakfast pie made with sausage (pork) and apples
# Chicken breasts stuffed with bacon and mozzarella
# Beef stew made with beef, carrots and potatoes
# Grilled salmon seasoned with salt and pepper
# Chicken breasts stuffed with bacon and mozzarella
# Chopped French duck confit preserved by duck oil
# Spaghetti using year round egg catsup noodles, made with sauce consisting of ground beef meat, bacon (pork) meat, cheddar cheese, parmesan, and tomatoes.
# Low fat baked breakfast pie made with sausage (pork) and apples
# High protein skillet with rice and vegetables
# Soup made with ground turkey that is low fat, high carb
# Chinese salad made of eggplant and zucchini, flavoured with soy sauce
# Poke of tofu, mushroom and tomatoes
# Chicken breasts stuffed with bacon and mozzarella
# Beef stew made with beef, carrots and potatoes
# High protein skillet with rice and vegetables
# Low fat baked breakfast pie made with sausage (pork) and apples
# Chopped French duck confit preserved by duck oil
# Spaghetti using year round egg catsup noodles, made with sauce consisting of ground beef meat, bacon (pork) meat, cheddar cheese, parmesan, and tomatoes.
# Soup made with ground turkey that is low fat, high carb
# Chinese salad made of eggplant and zucchini, flavoured with soy sauce
# Poke of tofu, mushroom and tomatoes
# Queso made from melted cheese and chili peppers
