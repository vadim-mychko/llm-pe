# %%
import pandas as pd
import numpy as np

# %%
# Enter path to data folder on your device. 
# Data can be downloaded from https://grouplens.org/datasets/movielens/ as "ml-25m.zip" under MovieLens 25M Dataset
# ~62K movies in total
movie_lens_path = "/Users/david/Documents/Research2324/Sanner/ml-25m/"

# %%
movie_lens_path = "C:/Users/anton/source/data/SIGIR24/MovieLens25M/"

# %%
movie_df = pd.read_csv(movie_lens_path + "movies.csv")

#Make 'genres' column comma seperated, not '|' seperated
movie_df['genres'] = movie_df['genres'].str.replace('|', ', ', regex=False)

movie_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                             genres
# 0  Adventure, Animation, Children, Comedy, Fantasy
# 1                     Adventure, Children, Fantasy
# 2                                  Comedy, Romance
# 3                           Comedy, Drama, Romance
# 4                                           Comedy

# %%
tags_df = pd.read_csv(movie_lens_path + "tags.csv")
tags_df.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %% [markdown]
# ### Filter movies be in top 10% rating count and have 20+ tags

# %%
#select movies with top 10% rating count
ratings_df = pd.read_csv(movie_lens_path + 'ratings.csv')
rating_cnt_df = ratings_df['movieId'].value_counts()

top_10_perc_cnt = int(len(movie_df)*0.1)

top_10_perc_rating_cnts = rating_cnt_df.head(top_10_perc_cnt)

# %%
top_10_perc_rating_cnts
# Out:
# movieId
# 356       81491
# 318       81482
# 296       79672
# 593       74127
# 2571      72674
#           ...
# 61255       366
# 71619       366
# 58839       366
# 134528      366
# 8799        366
# Name: count, Length: 6242, dtype: int64

# %%
top_10_percent_movie_ids = set(top_10_perc_rating_cnts.index)

# %%
#select movies with at least 20 unique tags

# Filter 'tags_df' for movies in 'top_10_percent_movie_ids'
filtered_tags_df = tags_df[tags_df['movieId'].isin(top_10_percent_movie_ids)]

#Group by 'movieId' and count unique tags
unique_tag_counts = filtered_tags_df.groupby('movieId')['tag'].nunique()

#Filter for movies with at least 20 unique tags
movies_20_plus_tags = unique_tag_counts[unique_tag_counts >= 20].index.tolist()

# %%
#gives 4425 movies (using MovieLens25M)
len(movies_20_plus_tags)
# Out:
# 4425

# %% [markdown]
# ### Randomly select 100 movies and get their top 20 most frequent tags

# %%
import random

# %%
random.seed(42)
random_100_movie_ids = random.sample(movies_20_plus_tags, 100)

# %%
#Filter 'tags_df' for these 100 movies
filtered_100_tags_df = tags_df[tags_df['movieId'].isin(random_100_movie_ids)]

#tag counts for each movie:
grouped_tags = filtered_100_tags_df.groupby(['movieId', 'tag']).size().reset_index(name='count')

# for each movie, select the top 20 tags
top_20_tags_per_movie = grouped_tags.groupby('movieId').apply(lambda x: x.nlargest(20, 'count')).reset_index(drop = True)

# %%
top_20_tags_per_movie
# Out:
#       movieId                tag  count
# 0         123           stylized     17
# 1         123          dreamlike     12
# 2         123         loneliness     12
# 3         123         reflective     12
# 4         123          Hong Kong      9
# ...       ...                ...    ...
# 1995   197175        badass girl      5
# 1996   197175            cliched      5
# 1997   197175            romance      5
# 1998   197175     uncanny valley      5
# 1999   197175  Jennifer Connelly      4
#
# [2000 rows x 3 columns]

# %%
# Create a DataFrame from the 'top_20_tags_per_movie' with 'movieId' as index and concatenated tags as values
tags_concatenated = top_20_tags_per_movie.groupby('movieId')['tag'].apply(lambda x: ', '.join(x)).reset_index(name='top_20_tags')

#Merge the concatenated tags with the filtered_movie_df
filtered_movie_df = movie_df[movie_df['movieId'].isin(random_100_movie_ids)]
filtered_100_df = pd.merge(filtered_movie_df, tags_concatenated, on='movieId', how='left')

#randomize rows
filtered_100_df = filtered_100_df.sample(frac=1).reset_index(drop=True)

# %%
filtered_100_df
# Out:
#     movieId                                              title  \
# 0     74727   Gentlemen of Fortune (Dzhentlmeny udachi) (1972)
# 1      7293                              50 First Dates (2004)
# 2      1912                                Out of Sight (1998)
# 3      6873                         Intolerable Cruelty (2003)
# 4     64034  Boy in the Striped Pajamas, The (Boy in the St...
# ..      ...                                                ...
# 95     4519                       Land Before Time, The (1988)
# 96     4967                               No Man's Land (2001)
# 97    91653                             We Bought a Zoo (2011)
# 98      565                                      Cronos (1993)
# 99     5065                     Mothman Prophecies, The (2002)
#
#                                        genres  \
# 0               Comedy, Crime, Drama, Mystery
# 1                             Comedy, Romance
# 2     Comedy, Crime, Drama, Romance, Thriller
# 3                             Comedy, Romance
# 4                                  Drama, War
# ..                                        ...
# 95    Adventure, Animation, Children, Fantasy
# 96                                 Drama, War
# 97                              Comedy, Drama
# 98                              Drama, Horror
# 99  Drama, Fantasy, Horror, Mystery, Thriller
#
#                                           top_20_tags
# 0   Soviet Union, classic, comedy, Russian, underc...
# 1   Adam Sandler, Drew Barrymore, Romance, Comedy,...
# 2   George Clooney, Jennifer Lopez, comedy romance...
# 3   screwball comedy, divorce, lawyers, George Clo...
# 4   World War II, Holocaust, touching, Friendship,...
# ..                                                ...
# 95  dinosaurs, friendship, classic, animation, nos...
# 96  No Happy End, complex characters, ethnic confl...
# 97  feel-good, Family, predictable, Animals, Matt ...
# 98  Guillermo del Toro, slow, Criterion, atmospher...
# 99  supernatural, Richard Gere, pointless, Debra M...
#
# [100 rows x 4 columns]

# %%
filtered_100_df[filtered_100_df['title'] == '5 Centimeters per Second (By\u00f4soku 5 senchim\u00eatoru) (2007)']
# Out:
#     movieId                                              title  \
# 84    64993  5 Centimeters per Second (Byôsoku 5 senchimêto...
#
#                        genres  \
# 84  Animation, Drama, Romance
#
#                                           top_20_tags
# 84  melancholic, bittersweet, visually stunning, a...

# %% [markdown]
# ### Make JSON File

# %%
movies_dict = {}

for idx, row in filtered_100_df.iterrows():
    description = f" Movie Title: {row['title']} \n Genres: {row['genres']} \n Tags: {row['top_20_tags']}"
    movies_dict[str(idx)] = {'description': description}

# %%
import json

with open('data/ml25M_100_movie_sample_n.json', 'w') as json_file:
    json.dump(movies_dict, json_file, indent=4)

# %% [markdown]
# ### Trim 100 movies to 50

# %%
with open('data/ml25M_100_movie_sample.json', 'r') as json_file:
    jdata = json.load(json_file)

# %%
keep_ids = []
for val in range(50):
    keep_ids.append(str(val))

# %%
final_dict = {key: jdata[key] for key in keep_ids}
final_dict
# Out:
# {'0': {'description': ' -Movie Title: Tomb Raider (2018) \n -Genres: Action, Adventure, Fantasy \n -Tags: adventure, Alicia Vikander, video game adaptation, female protagonist, action, strong female lead, island, treasure hunt, boring, father daughter relationship, remake, based on a video game, reboot, predictable, action heroine, archaeology, dialogue, adaptation, bad remake, perfectly enjoyable'},
#  '1': {'description': " -Movie Title: Pirates of the Caribbean: At World's End (2007) \n -Genres: Action, Adventure, Comedy, Fantasy \n -Tags: Johnny Depp, pirates, adventure, Keira Knightley, comedy, Orlando Bloom, anti-hero, treasure, quirky, seafaring, Geoffrey Rush, sequel, swashbuckler, funny, surreal, big budget, confusing, BORING!, stupid ending, Disney"},
#  '2': {'description': ' -Movie Title: Laura (1944) \n -Genres: Crime, Film-Noir, Mystery \n -Tags: film noir, black and white, Vincent Price, murder, Oscar (Best Cinematography), murder mystery, noir, Dana Andrews, Gene Tierney, 1940s, Clifton Webb, adapted from:book, plot twist, romance, AFI 100 (Thrills), National Film Registry, Otto Preminger, author:Vera Caspary, famous theme song, investigation'},
#  '3': {'description': ' -Movie Title: Last Temptation of Christ, The (1988) \n -Genres: Drama \n -Tags: jesus, christian, Martin Scorsese, based on a book, christianity, controversial, Criterion, good soundtrack, religion, violence, Biblical, Nudity (Topless), blasphemy, edgy, god, soundtrack, storytelling, 70mm, A Última Tentação de Cristo, Bible'},
#  '4': {'description': ' -Movie Title: Abraham Lincoln: Vampire Hunter (2012) \n -Genres: Action, Fantasy, Horror, Thriller \n -Tags: vampires, American Civil War, Predictable, Stupid, America, Revenge, Speeches, US history, 19th century, 3d, Action, Axe, Benjamin Walker, Civil War, Civil war, Dead child, Dimensionalized 2-D to 3-D, History, Horror, Mother'},
#  '5': {'description': ' -Movie Title: Santa Sangre (1989) \n -Genres: Drama, Horror, Mystery, Thriller \n -Tags: atmospheric, Alejandro Jodorowsky, weird, stylized, surreal, circus, clowns, eerie, enigmatic, disturbing, Betamax, Down  syndrome, Jodorowsky, cerebral, creepy, tense, vhs, visceral, visually appealing, CLV'},
#  '6': {'description': ' -Movie Title: August Rush (2007) \n -Genres: Drama, Musical \n -Tags: inspirational, power of music, music, love of music, thought-provoking, uplifting and compelling, unique, Freddie Highmore, Jonathan Rhys Meyers, Musical, KAF, Kaki King, Kirsten Sheridan, Robin Williams, builds up, children, different but very good, forbidden love, guitar, holes in the plot'},
#  '7': {'description': ' -Movie Title: Blair Witch Project, The (1999) \n -Genres: Drama, Horror, Thriller \n -Tags: low budget, creepy, scary, found footage, forest, atmospheric, original, Handycam, horror, suspense, mimics documentary-style, mockumentary, witch, boring, disturbing, "found footage", overrated, unsteady-cam, wilderness, Golden Raspberry (Worst Actress)'},
#  '8': {'description': ' -Movie Title: Martyrs (2008) \n -Genres: Horror \n -Tags: torture, disturbing, extremely violent, shocking, martyrdom, psychological, New French Extremity, bloody, ending, plot twist, horror, violent, lesbian subtext, unusual, atmospheric, probably hardest gore ever, revenge, New French Extremism, ambiguous ending, child abuse'},
#  '9': {'description': ' -Movie Title: Piano, The (1993) \n -Genres: Drama, Romance \n -Tags: atmospheric, New Zealand, beautiful, 19th century, adultery, Oscar (Best Actress), erotic, melancholy, sexuality, Holly Hunter, Oscar (Best Supporting Actress), great acting, intense, lyrical, Harvey Keitel, Jane Campion, Nudity (Full Frontal - Notable), good soundtrack, great soundtrack, stylized'},
#  '10': {'description': " -Movie Title: Terms of Endearment (1983) \n -Genres: Comedy, Drama \n -Tags: Oscar (Best Picture), sentimental, Jack Nicholson, tear jerker, Oscar (Best Actress), Oscar (Best Directing), Oscar (Best Supporting Actor), marriage, James L. Brooks, MOTHERS AND DAUGHTERS, Shirley MacLaine, adapted from:book, astronauts, terminal illness, 100 Essential Female Performances, 1940's, 1950s, 1960s, 1970s, 3 tissues"},
#  '11': {'description': ' -Movie Title: Proposition, The (2005) \n -Genres: Crime, Drama, Western \n -Tags: Australia, nick cave, Australian, Intense, brutality, Colonial, David Wenham, Guy Pearce, Violent, retribution, soundtrack, western, whipping, Annemari, Australian History, BGAB LRC, DIVX, Flies, Gritty, John Hillcoat'},
#  '12': {'description': ' -Movie Title: Bernie (2011) \n -Genres: Comedy, Crime, Drama \n -Tags: black comedy, Richard Linklater, Jack Black, mockumentary, funeral home, true story, mathew mcconaughey, Gay Character, Texas, amateur theater, confession of crime, corpse in freezer, duringcreditsstinger, embezzlement, estranged family member, funeral director, hick, hidden corpse, jury trial, missing persons case'},
#  '13': {'description': " -Movie Title: Naked Gun: From the Files of Police Squad!, The (1988) \n -Genres: Action, Comedy, Crime, Romance \n -Tags: parody, Leslie Nielsen, Funny as hell, slapstick, spoof, comedy, Leslie Neilsen, ZAZ, farce, fart jokes, police, David Zucker, hilarious, screwball, 1980s, BD-R, Betamax, CLV, Can't remember, Jim's list"},
#  '14': {'description': ' -Movie Title: Last Action Hero (1993) \n -Genres: Action, Adventure, Comedy, Fantasy \n -Tags: arnold, Arnold Schwarzenegger, parody, deconstruction, campy, movie magic, quirky, John McTiernan, breaking the fourth wall, cheesy, fun, ridiculous, stupid, Writer: Shane Black, Writer: Zak Penn, action, cult film, fantasy, kid flick, stylized'},
#  '15': {'description': ' -Movie Title: One Hour Photo (2002) \n -Genres: Drama, Thriller \n -Tags: Robin Williams, creepy, suspense, dark, stalker, psychotic tendencies, psychological, strange story, bizarre, photography, Nudity (Topless), psychopaths, Dream Sequence, Mark Romanek, serial killer, great acting, horror, one of the best movies ever, oppression, sad but good'},
#  '16': {'description': " -Movie Title: Dracula (Bram Stoker's Dracula) (1992) \n -Genres: Fantasy, Horror, Romance, Thriller \n -Tags: vampires, vampire, based on a book, gothic, Anthony Hopkins, Keanu Reeves, Winona Ryder, Gary Oldman, Nudity (Topless), gary oldman, erotic, visually rich, Francis Ford Coppola, Oscar (Best Makeup), dracula, Bruce Willis, Oscar (Best Costume Design), adapted from:book, stylized, Oscar (Best Effects - Visual Effects)"},
#  '17': {'description': ' -Movie Title: Lost World: Jurassic Park, The (1997) \n -Genres: Action, Adventure, Sci-Fi, Thriller \n -Tags: dinosaurs, Steven Spielberg, spielberg, Jeff Goldblum, Julianne Moore, based on a book, Adventure, Michael Crichton, Vince Vaughn, inferior sequel, franchise, special effects, Dinosaurs, Pete Postlethwaite, Richard Attenborough, cash-in sequel, environmental, jungle, nature vs. civilization, seen more than once'},
#  '18': {'description': " -Movie Title: Autumn Sonata (Höstsonaten) (1978) \n -Genres: Drama \n -Tags: bleak, Criterion, Ingmar Bergman, autumnal, deliberate, reflective, 100 Essential Female Performances, claustrophobic, pianist, siblings, sincerity, BD-R, CLV, New World Pictures, Tumey's DVDs, a list, caretaker, dvd, independent woman, invalid"},
#  '19': {'description': ' -Movie Title: Cocoon (1985) \n -Genres: Comedy, Sci-Fi \n -Tags: aliens, alien, old age, Oscar (Best Supporting Actor), Ron Howard, senior citizens, Nudity (Rear), Spherical Blow-Up, soft, 1980s, 70mm, BD-R, Brian Dennehy, CLV, Futuristmovies.com, Hume Cronyn, Jessica Tandy, NO_FA_GANES, Steve Guttenberg, benign alien'},
#  '20': {'description': ' -Movie Title: Man on Fire (2004) \n -Genres: Action, Crime, Drama, Mystery, Thriller \n -Tags: Denzel Washington, revenge, Christopher Walken, kidnapping, action, redemption, bodyguard, Dakota Fanning, great cinematography, twists & turns, vengeance, friendship, Torture, ending, faith, mexico, Suicide, makes you cry, Tony Scott, alcoholism'},
#  '21': {'description': " -Movie Title: Before the Devil Knows You're Dead (2007) \n -Genres: Crime, Drama, Thriller \n -Tags: Philip Seymour Hoffman, Sidney Lumet, Marisa Tomei, Nudity (Topless), Albert Finney, non-linear, Ethan Hawke, acting, R, disjointed timeline, nonlinear, human fallibility, Nudity (Topless - Notable), compelling, tense, jewelry store, sibling rivalry, social commentary, Bechdel Test:Fail, New York City"},
#  '22': {'description': ' -Movie Title: All Quiet on the Western Front (1930) \n -Genres: Action, Drama, War \n -Tags: World War I, Oscar (Best Picture), anti-war, based on a book, German perspective, Oscar (Best Directing), imdb top 250, literary adaptation, war ugliness, world war I, AFI #54, BEST PICTURE, Lewis Milestone, military, war, war movie, 100 Greatest Movies, AFI 100, Arnold Lucy, BD-R'},
#  '23': {'description': ' -Movie Title: Gentlemen of Fortune (Dzhentlmeny udachi) (1972) \n -Genres: Comedy, Crime, Drama, Mystery \n -Tags: Soviet Union, classic, comedy, Russian, undercover cop, Evgeni Leonov, prison escape, quotable, Aleksandr Seryj, crime, criminal comedy, kindergarten, prison, 01/11, 01/12, 02/11, 03/11, 04/11, 05/11, 06/11'},
#  '24': {'description': ' -Movie Title: Drugstore Cowboy (1989) \n -Genres: Crime, Drama \n -Tags: drugs, addiction, Gus Van Sant, drug abuse, DRUG ADDICTION, Portland, existential, philosophy, 1970s, CLV, DVD-Video, Heather Graham, Oregon, To See, Trainspotting minus the good parts, atmospheric, burglary, contemplative, crime, drama'},
#  '25': {'description': " -Movie Title: Legend of 1900, The (a.k.a. The Legend of the Pianist on the Ocean) (Leggenda del pianista sull'oceano) (1998) \n -Genres: Drama \n -Tags: great soundtrack, music, ennio morricone, Tim Roth, piano, genius, ocean, ship, Giuseppe Tornatore, Leonardo DiCaprio, attachment, character, child prodigy, classic, composition, cruise ship, dialogue, dream, fondling, foreign"},
#  '26': {'description': " -Movie Title: No Man's Land (2001) \n -Genres: Drama, War \n -Tags: No Happy End, complex characters, ethnic conflict, war, Oscar (Best Foreign Language Film), thought-provoking, social commentary, foreign, human nature, satire, comedy, disturbing, emotional, intense, tense, want to see again, Absurdity of War, Bosnian, DIVX, Danis Tanovic"},
#  '27': {'description': " -Movie Title: St. Elmo's Fire (1985) \n -Genres: Drama, Romance \n -Tags: Brat Pack, friendship, Rob Lowe, 80's classic, Emilio Estevez, post-college, teen, 1980s, Nudity (Topless - Brief), Washington DC, college graduate, friends with issues, Ally Sheedy, Andie MacDowell, Andrew McCarthy, CLV, Demi Moore, Judd Nelson, Stalking, a list"},
#  '28': {'description': " -Movie Title: UHF (1989) \n -Genres: Comedy \n -Tags: Weird Al, Michael Richards, quirky, Weird Al Yankovic, television, Fran Drescher, Friday night movie, 80's classic, BD-R, David Bowie, amateurish, cult film, game show, goofy, loser, music spoof, music video, parody, satire, setting:TV network"},
#  '29': {'description': ' -Movie Title: Man from Earth, The (2007) \n -Genres: Drama, Sci-Fi \n -Tags: philosophical, thought-provoking, intellectual, Excellent use of dialogue, dialogue driven, unique, intelligent, immortality, sci-fi, entirely dialogue, excellent script, religion, Underrated, Bad acting, science fiction, dialogue, low budget, psychological, history, one set'},
#  '30': {'description': ' -Movie Title: Metropolis (2001) \n -Genres: Animation, Sci-Fi \n -Tags: anime, visually appealing, robots, androids, deus ex machina, future, Japan, Sad Ending, cookie-cutter, psychopath, tezuka, DVD-Video, Rintaro, See: Metropolis (1927), animation, based on comic, childish style, comic book, control, homage'},
#  '31': {'description': ' -Movie Title: Bad Education (La mala educación) (2004) \n -Genres: Drama, Thriller \n -Tags: gay, Catholicism, child abuse, queer, sexual abuse, sexuality, Pedro Almodovar, stylized, Christianity, enigmatic, movie business, religion, revenge, spanish, Gay sex, school, Gael Garcia Bernal, choir, drag queens, drugs'},
#  '32': {'description': ' -Movie Title: How High (2001) \n -Genres: Comedy \n -Tags: drugs, Weed, college, marijuana, weed, Comedy Need to See, Harvard, Jesse Dylan, Jokes, baby powder, cannabis, canon, carpet, corpse in coffin, cult film, dean, dove, doves, drug deal, grave robbing'},
#  '33': {'description': ' -Movie Title: Cage aux Folles, La (1978) \n -Genres: Comedy \n -Tags: gay, queer, Criterion, French, comedy, cross dressing, funny, hilarious, 1970s, BD-R, CLV, Crossdressing, Edouard Molinaro, Homosexuality, Remade, adapted from:play, based on a play, cabaret, camp, contrasting lifestyles'},
#  '34': {'description': ' -Movie Title: We Bought a Zoo (2011) \n -Genres: Comedy, Drama \n -Tags: feel-good, Family, predictable, Animals, Matt Damon, Scarlett Johansson, family bonds, Adventure, Coping With Loss, Sense of Adventure, lacklustre, zoo, Widower, animal, blocked road, countryside, hard work, rain, script, teenager'},
#  '35': {'description': " -Movie Title: Crimes and Misdemeanors (1989) \n -Genres: Comedy, Crime, Drama \n -Tags: Woody Allen, adultery, philosophical, realistic, 16.01.06, Bibliothek, DVD-Video, Woody Allen classic, banal philosophy, ending, need to own, seen, add to prospects list, assassin, brother-in-law, doctor, documentary filmmaking, douchbag instruktÃ¸ren er lidt en kliche i starten hvor han stopper midt i samtalen og siger tilsin diktafon note to self idea for tv series..., ellers okay.., erlend's DVDs"},
#  '36': {'description': ' -Movie Title: Secret of Kells, The (2009) \n -Genres: Animation, Fantasy \n -Tags: stylized, animation, beautiful, medieval, Atmospheric, art, magic, nature, celtic, vikings, fantasy, 2D animation, Ireland, monks, not for kids, Nora Twomey, Tomm Moore, Underdeveloped, barbarian, children'},
#  '37': {'description': ' -Movie Title: Chungking Express (Chung Hing sam lam) (1994) \n -Genres: Drama, Mystery, Romance \n -Tags: stylized, dreamlike, loneliness, reflective, Hong Kong, good music, lyrical, Criterion, melancholy, Wong Kar Wai, cinematography, fanciful, obsession, urbane, scenic, BREAKUPS AND DIVORCES, Takeshi Kaneshiro, amelie-esque, cops, excellent'},
#  '38': {'description': " -Movie Title: Arsenic and Old Lace (1944) \n -Genres: Comedy, Mystery, Thriller \n -Tags: dark comedy, murder, Cary Grant, screwball comedy, insanity, Frank Capra, based on a play, Everyone has a crazy Aunt.  But two?, Funny as hell, frantic, hysterical, newlyweds, to see: classic, AFI 100 (Laughs), BD-R, Friends Should See, Funny, Stageplay, Tumey's DVDs, Well Plotted"},
#  '39': {'description': ' -Movie Title: Breach (2007) \n -Genres: Drama, Thriller \n -Tags: spying, corruption, espionage, true story, FBI, Chris Cooper, based on a true story, spy, PG-13, ominous, tense, Catholicism, Christianity, Washington DC, conspiracy, matter-of-fact, paranoid, religion, 2000s, BGAB LRC'},
#  '40': {'description': ' -Movie Title: Clash of the Titans (1981) \n -Genres: Action, Adventure, Fantasy, Romance \n -Tags: mythology, Claymation, Ancient Greeks, Greek mytholog, Classical Studies, Laurence Olivier, Ray Harryhausen, bad acting, stop motion, sword and sandal, BD-R, CLV, DVD-R, Desmond Davis, Myth, ancient greece, bad fx, bad screenplay, based on myths or folklore, giant bird'},
#  '41': {'description': " -Movie Title: Land Before Time, The (1988) \n -Genres: Adventure, Animation, Children, Fantasy \n -Tags: dinosaurs, friendship, classic, animation, nostalgic, Don Bluth, animated, Can't remember, TylsÃ¤, coming of age, coming-of-age, dead mother, dinosaur, earthquake, franchise, loss of loved one, my favourite kids movie, orphaned cartoon character, prehistoric, primitive time"},
#  '42': {'description': ' -Movie Title: Out of Sight (1998) \n -Genres: Comedy, Crime, Drama, Romance, Thriller \n -Tags: George Clooney, Jennifer Lopez, comedy romance, Steven Soderbergh, prison escape, stylish, heist, music, Don Cheadle, Edgar Award (Best Motion Picture), Elmore Leonard, Oscar Nominee: Adapted Screenplay, bank robbers, bank robbery, based on a book, chemistry between actors, kidnapping, love, love at first sight, prison'},
#  '43': {'description': ' -Movie Title: Mothman Prophecies, The (2002) \n -Genres: Drama, Fantasy, Horror, Mystery, Thriller \n -Tags: supernatural, Richard Gere, pointless, Debra Messing, Dull, Mark Pellington, Mind Bending, Suspense and Mystery, alien life-form, based on novel or book, boring, bridge, car wreck, chemical plant, chilling, death of wife, dream, dull, hallucination, hospital'},
#  '44': {'description': " -Movie Title: Love Me If You Dare (Jeux d'enfants) (2003) \n -Genres: Drama, Romance \n -Tags: Marion Cotillard, French, friendship, beautiful color, cruel characters, romance, Nudity (Topless - Notable), cross-sex friendship, escapist ending, excellent cinematography, fantastical imagery, France, bet, sad ending, Bibliothek, Guillaume Canet, dare, merry-go-round, Tumey's DVDs, Yann Samuell"},
#  '45': {'description': ' -Movie Title: Magnolia (1999) \n -Genres: Drama \n -Tags: multiple storylines, Philip Seymour Hoffman, Tom Cruise, melancholy, Paul Thomas Anderson, ensemble cast, coincidences, stylized, poignant, cynical, mindfuck, great acting, bleak, REDEMPTION, great soundtrack, religious overtones, addiction, drugs, DRUG ADDICTION, Julianne Moore'},
#  '46': {'description': ' -Movie Title: Alita: Battle Angel (2019) \n -Genres: Action, Romance, Sci-Fi, Thriller \n -Tags: cyberpunk, visually appealing, sci-fi, future, based on a manga, cyborg, post-apocalyptic, female protagonist, dystopia, technology, Christoph Waltz, martial arts, father figure, bad script, teenagers, badass girl, cliched, romance, uncanny valley, Jennifer Connelly'},
#  '47': {'description': ' -Movie Title: Gremlins 2: The New Batch (1990) \n -Genres: Comedy, Horror \n -Tags: Joe Dante, monster, Steven Spielberg, Wacky, sequel, 70mm, BD-Video, CLV, DVD-Video, Gizmo, Spherical Blow-Up, Zach Galligan, bat, cleverness, cowardliness, creatures, current, dying and death, electric shock, family horror'},
#  '48': {'description': ' -Movie Title: Sure Thing, The (1985) \n -Genres: Comedy, Romance \n -Tags: road trip, college, cross country, Rob Reiner, relationships, teen movie, university, Daphne Zuniga, John Cusack, US college students, trip, coming of age, sexuality, subgenre:road trip, 80s, Betamax, Christmas, DVD-Video, california, swimming pool'},
#  '49': {'description': ' -Movie Title: Dangerous Liaisons (1988) \n -Genres: Drama, Romance \n -Tags: adultery, Paris, aristocracy, witty, John Malkovich, Keanu Reeves, 18th century, Uma Thurman, costume, femme fatale, adapted from:book, glenn close, period piece, seduction, Nudity (Topless - Notable), Stephen Frears, adapted from:play, based on  a book, based on a book, based on a play'}}

# %%
import json

with open('data/ml25M_50_movie_sample.json', 'w') as json_file:
    json.dump(final_dict, json_file, indent=4)

# %% [markdown]
# ### Randomly select 50 movies and get their top 20 most frequent tags

# %%
import random

# %%
random.seed(42)
random_50_movie_ids = random.sample(movies_20_plus_tags, 50)

# %%
#Filter 'tags_df' for these 50 movies
filtered_50_tags_df = tags_df[tags_df['movieId'].isin(random_50_movie_ids)]

#tag counts for each movie:
grouped_tags = filtered_50_tags_df.groupby(['movieId', 'tag']).size().reset_index(name='count')

# for each movie, select the top 20 tags
top_20_tags_per_movie = grouped_tags.groupby('movieId').apply(lambda x: x.nlargest(20, 'count')).reset_index(drop = True)

# %%
top_20_tags_per_movie
# Out:
#      movieId            tag  count
# 0        123       stylized     17
# 1        123      dreamlike     12
# 2        123     loneliness     12
# 3        123     reflective     12
# 4        123      Hong Kong      9
# ..       ...            ...    ...
# 995   190555  missing child      2
# 996   190555        mystery      2
# 997   190555            New      1
# 998   190555         acting      1
# 999   190555         boring      1
#
# [1000 rows x 3 columns]

# %%
# Create a DataFrame from the 'top_20_tags_per_movie' with 'movieId' as index and concatenated tags as values
tags_concatenated = top_20_tags_per_movie.groupby('movieId')['tag'].apply(lambda x: ', '.join(x)).reset_index(name='top_20_tags')

#Merge the concatenated tags with the filtered_movie_df
filtered_movie_df = movie_df[movie_df['movieId'].isin(random_50_movie_ids)]
filtered_50_df = pd.merge(filtered_movie_df, tags_concatenated, on='movieId', how='left')

#randomize rows
filtered_50_df = filtered_50_df.sample(frac=1).reset_index(drop=True)

# %%
filtered_50_df
# Out:
#     movieId                                              title  \
# 0      2710                    Blair Witch Project, The (1999)
# 1      1927              All Quiet on the Western Front (1930)
# 2      2146                             St. Elmo's Fire (1985)
# 3     90249                                  Real Steel (2011)
# 4      4010                         Brewster's Millions (1985)
# 5      2022              Last Temptation of Christ, The (1988)
# 6      2020                          Dangerous Liaisons (1988)
# 7      5065                     Mothman Prophecies, The (2002)
# 8      3095                        Grapes of Wrath, The (1940)
# 9      3868  Naked Gun: From the Files of Police Squad!, Th...
# 10     6533                             What's Up, Doc? (1972)
# 11    74727   Gentlemen of Fortune (Dzhentlmeny udachi) (1972)
# 12      485                            Last Action Hero (1993)
# 13     1544              Lost World: Jurassic Park, The (1997)
# 14     4705                         Cage aux Folles, La (1978)
# 15   190555                                   Searching (2018)
# 16     4519                       Land Before Time, The (1988)
# 17    55872                                 August Rush (2007)
# 18     7445                                 Man on Fire (2004)
# 19     4967                               No Man's Land (2001)
# 20    36519                               Transporter 2 (2005)
# 21    95207             Abraham Lincoln: Vampire Hunter (2012)
# 22    73290  Hachiko: A Dog's Story (a.k.a. Hachi: A Dog's ...
# 23      509                                  Piano, The (1993)
# 24     1297                                 Real Genius (1985)
# 25     3019                            Drugstore Cowboy (1989)
# 26      613                                   Jane Eyre (1996)
# 27     5540                         Clash of the Titans (1981)
# 28      565                                      Cronos (1993)
# 29     7293                              50 First Dates (2004)
# 30    48516                               Departed, The (2006)
# 31     6959                                    Timeline (2003)
# 32    49396          Tenacious D in The Pick of Destiny (2006)
# 33      942                                       Laura (1944)
# 34      973                               Meet John Doe (1941)
# 35     6971                           Europa (Zentropa) (1991)
# 36    39381                            Proposition, The (2005)
# 37     1573                                    Face/Off (1997)
# 38     6873                         Intolerable Cruelty (2003)
# 39    55444                                     Control (2007)
# 40     1958                         Terms of Endearment (1983)
# 41    41569                                   King Kong (2005)
# 42     4826                            Big Red One, The (1980)
# 43     1732                           Big Lebowski, The (1998)
# 44   135288                                  Mr. Holmes (2015)
# 45    74553                        Secret of Kells, The (2009)
# 46     1912                                Out of Sight (1998)
# 47      123      Chungking Express (Chung Hing sam lam) (1994)
# 48     4658                                Santa Sangre (1989)
# 49     2407                                      Cocoon (1985)
#
#                                          genres  \
# 0                       Drama, Horror, Thriller
# 1                            Action, Drama, War
# 2                                Drama, Romance
# 3                   Action, Drama, Sci-Fi, IMAX
# 4                                        Comedy
# 5                                         Drama
# 6                                Drama, Romance
# 7     Drama, Fantasy, Horror, Mystery, Thriller
# 8                                         Drama
# 9                Action, Comedy, Crime, Romance
# 10                                       Comedy
# 11                Comedy, Crime, Drama, Mystery
# 12           Action, Adventure, Comedy, Fantasy
# 13          Action, Adventure, Sci-Fi, Thriller
# 14                                       Comedy
# 15                                        Drama
# 16      Adventure, Animation, Children, Fantasy
# 17                               Drama, Musical
# 18      Action, Crime, Drama, Mystery, Thriller
# 19                                   Drama, War
# 20                      Action, Crime, Thriller
# 21            Action, Fantasy, Horror, Thriller
# 22                                        Drama
# 23                               Drama, Romance
# 24                                       Comedy
# 25                                 Crime, Drama
# 26                               Drama, Romance
# 27          Action, Adventure, Fantasy, Romance
# 28                                Drama, Horror
# 29                              Comedy, Romance
# 30                       Crime, Drama, Thriller
# 31                    Action, Adventure, Sci-Fi
# 32                   Adventure, Comedy, Musical
# 33                    Crime, Film-Noir, Mystery
# 34                                Comedy, Drama
# 35                              Drama, Thriller
# 36                        Crime, Drama, Western
# 37               Action, Crime, Drama, Thriller
# 38                              Comedy, Romance
# 39                                        Drama
# 40                                Comedy, Drama
# 41  Action, Adventure, Drama, Fantasy, Thriller
# 42                Action, Adventure, Drama, War
# 43                                Comedy, Crime
# 44                               Drama, Mystery
# 45                           Animation, Fantasy
# 46      Comedy, Crime, Drama, Romance, Thriller
# 47                      Drama, Mystery, Romance
# 48             Drama, Horror, Mystery, Thriller
# 49                               Comedy, Sci-Fi
#
#                                           top_20_tags
# 0   low budget, creepy, scary, found footage, fore...
# 1   World War I, Oscar (Best Picture), anti-war, b...
# 2   Brat Pack, friendship, Rob Lowe, 80's classic,...
# 3   robots, boxing, Science Fiction, father-son re...
# 4   richard pryor, Betamax, Can't remember, John C...
# 5   jesus, christian, Martin Scorsese, based on a ...
# 6   adultery, Paris, aristocracy, witty, John Malk...
# 7   supernatural, Richard Gere, pointless, Debra M...
# 8   Great Depression, adapted from:book, Social Dr...
# 9   parody, Leslie Nielsen, Funny as hell, slapsti...
# 10  Screwball Comedy, Madeline Kahn, Barbara Strie...
# 11  Soviet Union, classic, comedy, Russian, underc...
# 12  arnold, Arnold Schwarzenegger, parody, deconst...
# 13  dinosaurs, Steven Spielberg, spielberg, Jeff G...
# 14  gay, queer, Criterion, French, comedy, cross d...
# 15  well constructed, thriller, technology, invest...
# 16  dinosaurs, friendship, classic, animation, nos...
# 17  inspirational, power of music, music, love of ...
# 18  Denzel Washington, revenge, Christopher Walken...
# 19  No Happy End, complex characters, ethnic confl...
# 20  Jason Statham, cars, Kate Nauta, Good action, ...
# 21  vampires, American Civil War, Predictable, Stu...
# 22  dogs, Loyalty, based on a true story, Richard ...
# 23  atmospheric, New Zealand, beautiful, 19th cent...
# 24  college, science, smart comedy, nerds, enginee...
# 25  drugs, addiction, Gus Van Sant, drug abuse, DR...
# 26  adapted from:book, 19th century, Anna Paquin, ...
# 27  mythology, Claymation, Ancient Greeks, Greek m...
# 28  Guillermo del Toro, slow, Criterion, atmospher...
# 29  Adam Sandler, Drew Barrymore, Romance, Comedy,...
# 30  Leonardo DiCaprio, Martin Scorsese, Jack Nicho...
# 31  time travel, Michael Crichton, Gerard Butler, ...
# 32  Jack Black, Kyle Gass, comedy, rock and roll, ...
# 33  film noir, black and white, Vincent Price, mur...
# 34  Christianity, Frank Capra, acting, anti-fascis...
# 35  stylized, atmospheric, dreamlike, Lars von Tri...
# 36  Australia, nick cave, Australian, Intense, bru...
# 37  Nicolas Cage, John Travolta, action, John Woo,...
# 38  screwball comedy, divorce, lawyers, George Clo...
# 39  music, joy division, black and white, suicide,...
# 40  Oscar (Best Picture), sentimental, Jack Nichol...
# 41  Peter Jackson, adventure, Naomi Watts, monster...
# 42  World War II, tense, bleak, forceful, Classic,...
# 43  dark comedy, cult film, great dialogue, black ...
# 44  Ian McKellen, Sherlock Holmes, photography, Be...
# 45  stylized, animation, beautiful, medieval, Atmo...
# 46  George Clooney, Jennifer Lopez, comedy romance...
# 47  stylized, dreamlike, loneliness, reflective, H...
# 48  atmospheric, Alejandro Jodorowsky, weird, styl...
# 49  aliens, alien, old age, Oscar (Best Supporting...

# %% [markdown]
# ### Make JSON File

# %%
movies_dict = {}

for idx, row in filtered_50_df.iterrows():
    description = f" -Movie Title: {row['title']} \n -Genres: {row['genres']} \n -Tags: {row['top_20_tags']}"
    movies_dict[str(idx)] = {'description': description}

# %%
import json

with open('data/ml25M_50_movie_sample.json', 'w') as json_file:
    json.dump(movies_dict, json_file, indent=4)

# %% [markdown]
# ### Randomly select 16 movies and get their top 20 most frequent tags
# These are a subset of the above 100 at seed 42

# %%
import random

# %%
random.seed(42)
random_16_movie_ids = random.sample(movies_20_plus_tags, 16)

# %%
#Filter 'tags_df' for these 100 movies
filtered_16_tags_df = tags_df[tags_df['movieId'].isin(random_16_movie_ids)]

#tag counts for each movie:
grouped_tags = filtered_16_tags_df.groupby(['movieId', 'tag']).size().reset_index(name='count')

# for each movie, select the top 20 tags
top_20_tags_per_movie = grouped_tags.groupby('movieId').apply(lambda x: x.nlargest(20, 'count')).reset_index(drop = True)

# %%
top_20_tags_per_movie
# Out:
#      movieId                    tag  count
# 0        485                 arnold     32
# 1        485  Arnold Schwarzenegger     12
# 2        485                 parody     12
# 3        485         deconstruction      6
# 4        485                  campy      5
# ..       ...                    ...    ...
# 315   135288               dementia      1
# 316   135288              detective      1
# 317   135288            growing old      1
# 318   135288                    kid      1
# 319   135288         london england      1
#
# [320 rows x 3 columns]

# %%
# Create a DataFrame from the 'top_20_tags_per_movie' with 'movieId' as index and concatenated tags as values
tags_concatenated = top_20_tags_per_movie.groupby('movieId')['tag'].apply(lambda x: ', '.join(x)).reset_index(name='top_20_tags')

#Merge the concatenated tags with the filtered_movie_df
filtered_movie_df = movie_df[movie_df['movieId'].isin(random_16_movie_ids)]
filtered_16_df = pd.merge(filtered_movie_df, tags_concatenated, on='movieId', how='left')

#randomize rows
filtered_16_df = filtered_16_df.sample(frac=1).reset_index(drop=True)

# %%
filtered_16_df
# Out:
#     movieId                                  title  \
# 0      5540             Clash of the Titans (1981)
# 1      1732               Big Lebowski, The (1998)
# 2      1927  All Quiet on the Western Front (1930)
# 3       613                       Jane Eyre (1996)
# 4      4658                    Santa Sangre (1989)
# 5       509                      Piano, The (1993)
# 6      6873             Intolerable Cruelty (2003)
# 7       565                          Cronos (1993)
# 8      2146                 St. Elmo's Fire (1985)
# 9     74553            Secret of Kells, The (2009)
# 10     5065         Mothman Prophecies, The (2002)
# 11     2022  Last Temptation of Christ, The (1988)
# 12     2710        Blair Witch Project, The (1999)
# 13   135288                      Mr. Holmes (2015)
# 14     4826                Big Red One, The (1980)
# 15      485                Last Action Hero (1993)
#
#                                        genres  \
# 0         Action, Adventure, Fantasy, Romance
# 1                               Comedy, Crime
# 2                          Action, Drama, War
# 3                              Drama, Romance
# 4            Drama, Horror, Mystery, Thriller
# 5                              Drama, Romance
# 6                             Comedy, Romance
# 7                               Drama, Horror
# 8                              Drama, Romance
# 9                          Animation, Fantasy
# 10  Drama, Fantasy, Horror, Mystery, Thriller
# 11                                      Drama
# 12                    Drama, Horror, Thriller
# 13                             Drama, Mystery
# 14              Action, Adventure, Drama, War
# 15         Action, Adventure, Comedy, Fantasy
#
#                                           top_20_tags
# 0   mythology, Claymation, Ancient Greeks, Greek m...
# 1   dark comedy, cult film, great dialogue, black ...
# 2   World War I, Oscar (Best Picture), anti-war, b...
# 3   adapted from:book, 19th century, Anna Paquin, ...
# 4   atmospheric, Alejandro Jodorowsky, weird, styl...
# 5   atmospheric, New Zealand, beautiful, 19th cent...
# 6   screwball comedy, divorce, lawyers, George Clo...
# 7   Guillermo del Toro, slow, Criterion, atmospher...
# 8   Brat Pack, friendship, Rob Lowe, 80's classic,...
# 9   stylized, animation, beautiful, medieval, Atmo...
# 10  supernatural, Richard Gere, pointless, Debra M...
# 11  jesus, christian, Martin Scorsese, based on a ...
# 12  low budget, creepy, scary, found footage, fore...
# 13  Ian McKellen, Sherlock Holmes, photography, Be...
# 14  World War II, tense, bleak, forceful, Classic,...
# 15  arnold, Arnold Schwarzenegger, parody, deconst...

# %% [markdown]
# ### Make JSON File

# %%
movies_dict = {}

for idx, row in filtered_16_df.iterrows():
    description = f" -Movie Title: {row['title']} \n -Genres: {row['genres']} \n -Tags: {row['top_20_tags']}"
    movies_dict[str(idx)] = {'description': description}

# %%
import json

with open('data/ml25M_16_movie_sample.json', 'w') as json_file:
    json.dump(movies_dict, json_file, indent=4)

# %% [markdown]
# ### Few shot samples
# Some non-test movies with tags for few shot purposes.

# %%
random.seed(100000)
random_50_movie_ids = random.sample(movies_20_plus_tags, 50)

# %%
#remove overlapping ids with test data
random_50_movie_ids = [id for id in random_50_movie_ids if id not in random_100_movie_ids]

# %%
#Filter 'tags_df' for these 100 movies
filtered_50_tags_df = tags_df[tags_df['movieId'].isin(random_50_movie_ids)]

#tag counts for each movie:
grouped_tags = filtered_50_tags_df.groupby(['movieId', 'tag']).size().reset_index(name='count')

# for each movie, select the top 20 tags
top_20_tags_per_movie = grouped_tags.groupby('movieId').apply(lambda x: x.nlargest(20, 'count')).reset_index(drop = True)

# %%
top_20_tags_per_movie
# Out:
#      movieId                tag  count
# 0        337        Johnny Depp     32
# 1        337  Leonardo DiCaprio     22
# 2        337        bittersweet     20
# 3        337      coming of age     19
# 4        337     mental illness     15
# ..       ...                ...    ...
# 995   194016                sad      2
# 996   194016               wifi      2
# 997   194016        2020 relook      1
# 998   194016          Gal Gadot      1
# 999   194016             boring      1
#
# [1000 rows x 3 columns]

# %%
# Create a DataFrame from the 'top_20_tags_per_movie' with 'movieId' as index and concatenated tags as values
tags_concatenated = top_20_tags_per_movie.groupby('movieId')['tag'].apply(lambda x: ', '.join(x)).reset_index(name='top_20_tags')

#Merge the concatenated tags with the filtered_movie_df
filtered_movie_df = movie_df[movie_df['movieId'].isin(random_50_movie_ids)]
filtered_50_df = pd.merge(filtered_movie_df, tags_concatenated, on='movieId', how='left')

#randomize rows
filtered_50_df = filtered_50_df.sample(frac=1).reset_index(drop=True)

# %%
filtered_50_df
# Out:
#     movieId                                              title  \
# 0     52604                                    Fracture (2007)
# 1      2087                                   Peter Pan (1953)
# 2     96432                                     Lawless (2012)
# 3      6023            Band of Outsiders (Bande à part) (1964)
# 4     72393                            Fourth Kind, The (2009)
# 5     69526         Transformers: Revenge of the Fallen (2009)
# 6      1513      Romy and Michele's High School Reunion (1997)
# 7      6101                                     Missing (1982)
# 8      3091                                   Kagemusha (1980)
# 9     63808                 Class, The (Entre les murs) (2008)
# 10     4886                              Monsters, Inc. (2001)
# 11     5957                            Two Weeks Notice (2002)
# 12    70286                                  District 9 (2009)
# 13      370          Naked Gun 33 1/3: The Final Insult (1994)
# 14     4446           Final Fantasy: The Spirits Within (2001)
# 15    84152                                   Limitless (2011)
# 16     5444                               Lilo & Stitch (2002)
# 17     2344                               Runaway Train (1985)
# 18     1077                                     Sleeper (1973)
# 19    26150              Andrei Rublev (Andrey Rublyov) (1969)
# 20     3155                           Anna and the King (1999)
# 21   194016                   Ralph Breaks the Internet (2018)
# 22    56563                                   Helvetica (2007)
# 23     3258                           Death Becomes Her (1992)
# 24     1934                  You Can't Take It with You (1938)
# 25     4389                          Lost and Delirious (2001)
# 26    80463                         Social Network, The (2010)
# 27    91542          Sherlock Holmes: A Game of Shadows (2011)
# 28      337                 What's Eating Gilbert Grape (1993)
# 29     2528                                 Logan's Run (1976)
# 30    44929                                       Candy (2006)
# 31     1094                            Crying Game, The (1992)
# 32     1923                There's Something About Mary (1998)
# 33     2467  Name of the Rose, The (Name der Rose, Der) (1986)
# 34    66785  Good, the Bad, the Weird, The (Joheunnom nabbe...
# 35     2502                                Office Space (1999)
# 36    59141                               Son of Rambow (2007)
# 37     6713            Millennium Actress (Sennen joyû) (2001)
# 38   111364                                    Godzilla (2014)
# 39    65230                                 Marley & Me (2008)
# 40     1969  Nightmare on Elm Street 2: Freddy's Revenge, A...
# 41    74416                                   Fish Tank (2009)
# 42    40732                                Descent, The (2005)
# 43    90405                                     In Time (2011)
# 44      938                                        Gigi (1958)
# 45     5577                              Igby Goes Down (2002)
# 46    77798                  Nightmare on Elm Street, A (2010)
# 47    83349                           Green Hornet, The (2011)
# 48      506                                     Orlando (1992)
# 49     1023        Winnie the Pooh and the Blustery Day (1968)
#
#                                                genres  \
# 0                     Crime, Drama, Mystery, Thriller
# 1               Animation, Children, Fantasy, Musical
# 2                                        Crime, Drama
# 3                       Comedy, Crime, Drama, Romance
# 4                   Horror, Mystery, Sci-Fi, Thriller
# 5                     Action, Adventure, Sci-Fi, IMAX
# 6                                              Comedy
# 7                            Drama, Mystery, Thriller
# 8                                          Drama, War
# 9                                               Drama
# 10    Adventure, Animation, Children, Comedy, Fantasy
# 11                                    Comedy, Romance
# 12                          Mystery, Sci-Fi, Thriller
# 13                                     Action, Comedy
# 14              Adventure, Animation, Fantasy, Sci-Fi
# 15                                   Sci-Fi, Thriller
# 16             Adventure, Animation, Children, Sci-Fi
# 17                 Action, Adventure, Drama, Thriller
# 18                                     Comedy, Sci-Fi
# 19                                         Drama, War
# 20                                     Drama, Romance
# 21                                Animation, Children
# 22                                        Documentary
# 23                                    Comedy, Fantasy
# 24                                    Comedy, Romance
# 25                                              Drama
# 26                                              Drama
# 27  Action, Adventure, Comedy, Crime, Mystery, Thr...
# 28                                              Drama
# 29                          Action, Adventure, Sci-Fi
# 30                                     Drama, Romance
# 31                           Drama, Romance, Thriller
# 32                                    Comedy, Romance
# 33                    Crime, Drama, Mystery, Thriller
# 34                 Action, Adventure, Comedy, Western
# 35                                      Comedy, Crime
# 36                            Children, Comedy, Drama
# 37                          Animation, Drama, Romance
# 38                    Action, Adventure, Sci-Fi, IMAX
# 39                                      Comedy, Drama
# 40                                             Horror
# 41                                              Drama
# 42                 Adventure, Drama, Horror, Thriller
# 43                            Crime, Sci-Fi, Thriller
# 44                                            Musical
# 45                                      Comedy, Drama
# 46                          Fantasy, Horror, Thriller
# 47     Action, Comedy, Crime, Fantasy, Thriller, IMAX
# 48                            Drama, Fantasy, Romance
# 49                       Animation, Children, Musical
#
#                                           top_20_tags
# 0   Anthony Hopkins, twist ending, courtroom drama...
# 1   Disney, Peter Pan, pirates, animation, sword f...
# 2   Great Depression, Prohibition, Tom Hardy, Shia...
# 3   Jean-Luc Godard, French New Wave, Criterion, A...
# 4   Milla Jovovich, aliens, fake documentary, abdu...
# 5   robots, Megan Fox, bad plot, Shia LaBeouf, rid...
# 6   high school, Janeane Garofalo, comedy, Lisa Ku...
# 7   politics, Chile, Criterion, Golden Palm, Jack ...
# 8   Akira Kurosawa, Criterion, Japan, Tatsuya Naka...
# 9   high school, Laurent Cantet, Palme d'Or, reali...
# 10  Pixar, funny, Comedy, cute, animation, Animati...
# 11  Sandra Bullock, Hugh Grant, romantic comedy, R...
# 12  aliens, social commentary, sci-fi, intelligent...
# 13  parody, Comedy, Leslie Nielsen, Leslie Neilsen...
# 14  sci-fi, visually stunning, weak characters, al...
# 15  smart, thought provoking, visually appealing, ...
# 16  aliens, Disney, family, Hawaii, animation, pix...
# 17  prison escape, Andrei Konchalovsky, Andrey Kon...
# 18  Woody Allen, dystopia, slapstick, futuristic, ...
# 19  Andrei Tarkovsky, atmospheric, Criterion, long...
# 20  royalty, 19th century, Pam's list, Siam, based...
# 21  friendship, internet, Disney, existential cris...
# 22  typography, modernism, design, interviews, man...
# 23  Bruce Willis, Meryl Streep, immortality, Dark ...
# 24  Frank Capra, Oscar (Best Picture), James Stewa...
# 25  lesbian, boarding school, Mischa Barton, Piper...
# 26  computers, true story, Jesse Eisenberg, based ...
# 27  Robert Downey Jr., great cinematography, sherl...
# 28  Johnny Depp, Leonardo DiCaprio, bittersweet, c...
# 29  dystopia, post-apocalyptic, sci-fi, futuristic...
# 30  Australia, addiction, drug addiction, Heath Le...
# 31  transgender, twist ending, IRA, England, Irela...
# 32  Ben Stiller, Cameron Diaz, comedy, crude humor...
# 33  Sean Connery, medieval, based on a book, relig...
# 34  trains, Funny, Weird, desert, stylized, treasu...
# 35  satire, comedy, cult film, workplace, quirky, ...
# 36  bullying, exchange student, friendship, school...
# 37  Satoshi Kon, anime, romantic epic, touching, T...
# 38  Godzilla, bland hero, special effects, Monster...
# 39  dogs, Owen Wilson, marriage, Jennifer Aniston,...
# 40  character:Freddy Krueger, disfigurement, fire,...
# 41  realistic, realism, coming of age, disturbing,...
# 42  horror, claustrophobic, tense, suspense, cave,...
# 43  dystopia, sci-fi, thought-provoking, future, i...
# 44  Oscar (Best Picture), musical, coming of age, ...
# 45  Kieran Culkin, adolescence, dark humor, Claire...
# 46  remake, Jackie Earle Haley, unimaginative, Roo...
# 47  comic book, Seth Rogen, Unlikable protagonist,...
# 48  Tilda Swinton, gender identity, stylized, auth...
# 49  Disney, Disney animated feature, Pooh, Wolfgan...

# %% [markdown]
# ### Make JSON File

# %%
movies_dict = {}

for idx, row in filtered_50_df.iterrows():
    description = f" -Movie Title: {row['title']} \n -Genres: {row['genres']} \n -Tags: {row['top_20_tags']}"
    movies_dict[str(idx)] = {'description': description}

# %%
import json

with open('data/ml25M_FS_movie_sample.json', 'w') as json_file:
    json.dump(movies_dict, json_file, indent=4)

# %% [markdown]
# ### Old code

# %%
# USE THIS OPTION IF YOU WANT A RANDOM SAMPLE OF MOVIES WITH A SPECIFIC NUMBER OF TAGS

# Select 20 random movies from the trimmed set
np.random.seed(42)
random_movies = np.random.choice(trimmed_tags['movieId'].unique(), size=20)
movie_subset = random_movies

# %%
# USE THIS OPTION FOR HANDSELECTED MOVIES
selected_titles = [
    "Terminator, The (1984)", # 4 sci-fi movies
    "Matrix, The (1999)",
    "Interstellar (2014)",
    "Alien (1979)",
    "Tropic Thunder (2008)", # 4 comedy movies
    "Night at the Museum (2006)",
    "Shaun of the Dead (2004)",
    "Hot Fuzz (2007)",
    "Godfather, The (1972)", # 4 crime movies
    "Heat (1995)",
    "Goodfellas (1990)",
    "Reservoir Dogs (1992)",
    "Fantasia (1940)", # 4 animated movies
    "Toy Story 2 (1999)",
    "Aladdin (1992)",
    "Shrek (2001)",
]
movie_rows = movie_df[movie_df['title'].isin(selected_titles)]
movie_rows = movie_rows.drop_duplicates(subset=['title'])
movie_subset = movie_rows['movieId']
movie_rows
# Out:
#        movieId                       title  \
# 5            6                 Heat (1995)
# 580        588              Aladdin (1992)
# 840        858       Godfather, The (1972)
# 1062      1089       Reservoir Dogs (1992)
# 1182      1213           Goodfellas (1990)
# 1183      1214                Alien (1979)
# 1207      1240      Terminator, The (1984)
# 1249      1282             Fantasia (1940)
# 2480      2571          Matrix, The (1999)
# 3021      3114          Toy Story 2 (1999)
# 4201      4306                Shrek (2001)
# 8159      8874    Shaun of the Dead (2004)
# 10943    46972  Night at the Museum (2006)
# 11407    51255             Hot Fuzz (2007)
# 12591    61132       Tropic Thunder (2008)
# 21199   109487         Interstellar (2014)
#
#                                                   genres
# 5                                  Action|Crime|Thriller
# 580          Adventure|Animation|Children|Comedy|Musical
# 840                                          Crime|Drama
# 1062                              Crime|Mystery|Thriller
# 1182                                         Crime|Drama
# 1183                                       Horror|Sci-Fi
# 1207                              Action|Sci-Fi|Thriller
# 1249                  Animation|Children|Fantasy|Musical
# 2480                              Action|Sci-Fi|Thriller
# 3021         Adventure|Animation|Children|Comedy|Fantasy
# 4201   Adventure|Animation|Children|Comedy|Fantasy|Ro...
# 8159                                       Comedy|Horror
# 10943                         Action|Comedy|Fantasy|IMAX
# 11407                        Action|Comedy|Crime|Mystery
# 12591                        Action|Adventure|Comedy|War
# 21199                                        Sci-Fi|IMAX

# %%
final_tags = tags_df[tags_df['movieId'].isin(movie_subset)]
final_tags.head()
# Out:
#     userId  movieId                   tag   timestamp
# 51      87   109487          good science  1522676693
# 52      87   109487           Hans Zimmer  1522676679
# 53      87   109487  philosophical issues  1522676687
# 54      87   109487                sci-fi  1522676660
# 55      87   109487       science fiction  1522676703

# %%
test_row = final_tags[final_tags['movieId'] == 1666]
for tag in test_row['tag']:
    print(tag)

# %%
item_descs = {}
for item_count, item_id in enumerate(movie_subset):
    movie_df_row = movie_df[movie_df['movieId'] == item_id]
    # Set description as title
    title = movie_df_row['title'].item()
    item_desc = title + ", "
    # Append genres to the description
    genres = movie_df_row['genres'].item()
    genres = genres.split("|")
    for genre in genres:
        item_desc += (genre + ", ")

    # Append tags to the description
    movie_tags = final_tags[final_tags['movieId'] == item_id].drop_duplicates("tag")
    for i, aspect in enumerate(movie_tags['tag']):
        item_desc += aspect
        if (i > 15): # Cap the number of aspects at 15
            break
        if not (i == (len(movie_tags) - 1)):
            item_desc += ", "
    item_descs[str(item_count)] = {"description": item_desc, "name": title} # Using item_count instead of item_id 
print(item_descs)
# Out:
# {'0': {'description': "Heat (1995), Action, Crime, Thriller, imdb top 250, great acting, realistic action, suspense, Al Pacino, atmospheric, bank robbery, crime, Robert De Niro, tense, Val Kilmer, bank job, dialogue, heist, heist movie, long, Los Angeles, Michael Mann, visceral, bleak, slick, somber, witty, betrayal, cat and mouse, chase, crime epic, criminal mastermind, cult film, detective, ex-con, gang, honor, loner, los angeles, murder, neo-noir, obsession, one last job, robbery, thief, Recommendz Top Pick, gunfight, 1, overrated, philosophy, Natalie Portman, soundtrack, al pacino, electronic soundtrack, robert de niro, slow paced, blu-ray, mine, realistic, cliched, dumbed down, hollywoodization, lame, 7.5-FilmAffinity, es un poc de lo de sempre, too long, Ashley Judd, Bechdel Test:Fail, ensemble cast, police, relationships, individualism, heists, complex characters, setting:LA, who cares DVDs, CLV, Action, Crime, Heist, Jon Voight, Realistic, Third Act Problems, Al Pacino Vs Robert De Niro, authentic gunfights, In The Nucleus, btaege, HD MKV, Can't remember, seen 2011, synthesizer soundtrack, understated, Top 10 ever, netflix queue, adultery, career criminal, guns, professionals, real life, suicide, violent, need to own, Mary Kircher, Viviane Vives, Bibliothek, Tumey's DVDs, vontatott, amazing cast, Captivating, Bank Heist, Want, action, authenticity, Al and Robert, male-female relationship, ONE LAST HEIST, teenage girl, thieves, tragic end, R, R:language, R:violence, Seen 2010, tough guy", 'name': 'Heat (1995)'}, '1': {'description': "Aladdin (1992), Adventure, Animation, Children, Comedy, Musical, Katottava, aftercreditsstinger, animal sidekick, animation, arab, arabian nights, cartoon, comedy, flying carpet, genie, love, magic, magic lamp, monkey, musical, parrot, princess, sultan, three wishes, tiger, adventure, fairy tale, Fantasy, Disney, fun, funny, kids and family, lamp, magic carpet, marriage, wishes, 2D animation, Oscar (Best Music - Original Score), Robin Williams, artistic, good versus evil, middle east, rags to riches, Oscar (Best Music - Original Song), Arabia, fantasy, romance, Watched, Director: John Musker, Director: Ron Clements, Writer: Brian Pimental, Writer: Burny Mattinson, Writer: Chris Sanders, Writer: Daan Jippes, Writer: Darrell Rooney, Writer: David S. Smith, Writer: Francis Glebas, Writer: James Fujii, Writer: John Musker, Writer: Kevin Harkey, Writer: Kevin Lima, Writer: Kirk Hanson, Writer: Larry Leker, Writer: Patrick A. Ventura, Writer: Rebecca Rees, Writer: Roger Allers, Writer: Ron Clements, Writer: Sue C. Nichols, Writer: Ted Elliott, Writer: Terry Rossio, stereotypes, aliens, hard to rate (personal), disney, Disney Renaissance, soundtrack, Action, animated, children, hard to rate, music, prince abubu, Alan Menken, childhood, racist, Ron Clements, Disney animated feature, BD-Video, CAV, DVD-Video, Cartoon, rainy day watchlist, avi, Classic, coming of age, itaege, family comedy, want to own, seen more than once, DVD Collection, seen at the cinema, Animação, (s)vcd, Bearable Disney, Animation, Disney Classics, holes90s, young kids, Divx1, Aladdin, Arabian Nights, djinn, princess who doesn't like being a princess, family, excellent, kids, arabs", 'name': 'Aladdin (1992)'}, '2': {'description': "Godfather, The (1972), Crime, Drama, italian mafia, italy, Mafia, Marlon Brando, masterpiece, imdb top 250, Oscar (Best Picture), based on a book, catchy theme, organized crime, visceral, 100 Greatest Movies, classic, great acting, mafia, Al Pacino, epic, family, father son relationship, father-son relationship, great quotes, New York City, Nudity (Topless), violence, atmospheric, crime, oscar (best directing), robert de niro, too long, melancholy, Overrated, FALL FROM POWER, FATHERS AND SONS, lavish, MAFIA LIFE, menacing, RISE TO POWER, somber, stylized, sweeping, 1940s, 1950s, crime family, europe, italian american, lawyer, loss of loved one, love at first sight, mob boss, patriarch, rise to power, ...

# %%
import json

with open("./data/movielens_16_trimmed.json", "w") as output_file:
    json.dump(item_descs, output_file)
